# %%
# %%writefile single_file_rl_training_final.py
#!/usr/bin/env python3
"""
Enhanced Single-file implementation of Reinforcement Learning for Hierarchical Employee Training Optimization
Based on the research paper by Soumedhik Bharati, Rupsha Sadhukhan, Debanjali Saha

Improvements implemented:
- Fixed learning rate scheduling with StepLR for consistent learning
- Reduced entropy coefficient for more decisive policies
- Enhanced budget management through increased cost penalties
- Amplified efficiency bonuses to encourage budget awareness

Usage:
    python single_file_rl_training.py --mode train --episodes 3000 --cost-penalty 0.015
    python single_file_rl_training.py --mode compare --episodes 1000
"""

import os
import sys
import argparse
import time
import copy
from collections import defaultdict, deque
from typing import Dict, List, Tuple, Optional, Literal
from dataclasses import dataclass

# Core libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Gymnasium for RL environment
import gymnasium as gym
from gymnasium import spaces

# PyTorch for neural networks
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
from torch.optim.lr_scheduler import StepLR, ExponentialLR

# =============================================================================
# CONFIGURATION AND HYPERPARAMETERS
# =============================================================================

@dataclass
class TrainingConfig:
    """Configuration class for training parameters with budget-aware defaults"""
    # Training parameters
    num_episodes: int = 3000  # Increased for budget management learning
    gamma: float = 0.99
    learning_rate: float = 3e-4
    hidden_dim: int = 128
    use_baseline: bool = True
    entropy_coefficient: float = 0.001  # FIXED: Reduced from 0.01 for more decisive policy
    
    # Learning rate scheduling parameters
    lr_step_size: int = 750  # NEW: Steps before LR decay
    lr_gamma: float = 0.9    # NEW: LR decay factor
    
    # Environment parameters
    D: int = 8  # Number of skills
    K: int = 4  # Number of training modules
    alpha: List[float] = None  # Learning rates for modules
    beta: float = 0.01  # Reduced forgetting rate
    kappa: float = 1.2  # Reduced diminishing returns
    C_max: float = 120.0  # Increased budget
    
    # Reward strategy
    reward_strategy: Literal['basic', 'terminal', 'efficiency', 'hybrid'] = 'hybrid'
    cost_penalty: float = 0.01  # FIXED: Increased from 0.002 for budget awareness (5x increase)
    skill_amplifier: float = 1.0  # Amplify skill improvements
    terminal_bonus_multiplier: float = 1.5  # Terminal reward multiplier
    
    # Budget penalty parameters - FIXED: Increased for harsher budget enforcement
    base_budget_penalty: float = 4.0  # FIXED: Increased from 2.0
    max_budget_penalty: float = 8.0   # FIXED: Increased from 4.0
    
    # Logging and saving
    log_interval: int = 25  # More frequent logging for better monitoring
    save_interval: int = 500  # Less frequent saves for faster training
    model_save_path: str = 'models/employee_training_model.pth'
    plot_save_path: str = 'plots/'
    
    # Evaluation parameters
    eval_episodes: int = 100
    eval_render: bool = False
    
    def __post_init__(self):
        if self.alpha is None:
            self.alpha = [0.3, 0.25, 0.2, 0.35]
        
        # Validate configuration
        if self.entropy_coefficient > 0.1:
            print(f"WARNING: High entropy coefficient ({self.entropy_coefficient}) may prevent policy convergence")
        
        if self.lr_step_size > self.num_episodes // 2:
            print(f"WARNING: LR step size ({self.lr_step_size}) is large relative to training episodes ({self.num_episodes})")
        
        # Budget management validation
        if self.cost_penalty < 0.005:
            print(f"INFO: Low cost penalty ({self.cost_penalty}) may lead to budget overruns")


# =============================================================================
# EMPLOYEE TRAINING ENVIRONMENT
# =============================================================================

class EmployeeTrainingEnv(gym.Env):
    """
    Enhanced Custom Gymnasium environment with budget-aware reward structure.
    """
    
    metadata = {"render_modes": ["human"]}
    
    def __init__(self, config: TrainingConfig):
        super().__init__()
        
        self.config = config
        self.D = config.D
        self.K = config.K
        self.beta = config.beta
        self.kappa = config.kappa
        self.C_max = config.C_max
        self.gamma = config.gamma
        
        # Learning rates for each training module
        self.alpha = config.alpha
        
        # Training module costs
        self.costs = [10.0, 15.0, 20.0, 12.0]
        
        # Define which sub-attributes each training module targets
        self.module_targets = {
            0: [0, 1],      # Technical Skills: Coding, Debugging
            1: [2, 3],      # Technical Skills: Testing, Architecture
            2: [4, 5],      # Soft Skills: Communication, Leadership
            3: [6, 7]       # Soft Skills: Teamwork, Problem-solving
        }
        
        # Cross-attribute synergy matrix
        self.synergy_matrix = self._initialize_synergy_matrix()
        
        # Gymnasium spaces
        self.observation_space = spaces.Box(low=0.0, high=1.0, shape=(self.D,), dtype=np.float32)
        self.action_space = spaces.Discrete(self.K)
        
        # Episode state
        self.current_skills = None
        self.current_cost = 0.0
        self.episode_length = 0
        self.max_episode_length = 50
        self.initial_skills = None  # Track initial state for terminal rewards
        
    def _initialize_synergy_matrix(self) -> np.ndarray:
        """Initialize the cross-attribute synergy matrix."""
        synergy = np.zeros((self.D, self.D))
        
        # Within technical skills
        synergy[0, 1] = synergy[1, 0] = 0.3  # Coding <-> Debugging
        synergy[0, 2] = synergy[2, 0] = 0.2  # Coding <-> Testing
        synergy[1, 2] = synergy[2, 1] = 0.4  # Debugging <-> Testing
        synergy[2, 3] = synergy[3, 2] = 0.3  # Testing <-> Architecture
        
        # Within soft skills
        synergy[4, 5] = synergy[5, 4] = 0.4  # Communication <-> Leadership
        synergy[4, 6] = synergy[6, 4] = 0.3  # Communication <-> Teamwork
        synergy[5, 6] = synergy[6, 5] = 0.2  # Leadership <-> Teamwork
        synergy[6, 7] = synergy[7, 6] = 0.3  # Teamwork <-> Problem-solving
        
        # Cross-domain synergies
        synergy[1, 7] = synergy[7, 1] = 0.15  # Debugging <-> Problem-solving
        synergy[3, 5] = synergy[5, 3] = 0.1   # Architecture <-> Leadership
        
        return synergy
    
    def reset(self, seed: Optional[int] = None, options: Optional[Dict] = None) -> Tuple[np.ndarray, Dict]:
        """Reset the environment to initial state."""
        super().reset(seed=seed)
        
        # Initialize skills randomly between 0.1 and 0.6
        self.current_skills = self.np_random.uniform(0.1, 0.6, size=self.D).astype(np.float32)
        self.initial_skills = self.current_skills.copy()  # Store initial state
        self.current_cost = 0.0
        self.episode_length = 0
        
        return self.current_skills.copy(), {}
    
    def step(self, action: int) -> Tuple[np.ndarray, float, bool, bool, Dict]:
        """Execute one step with enhanced budget penalty handling."""
        if action < 0 or action >= self.K:
            raise ValueError(f"Invalid action: {action}")
        
        # Calculate cost and check budget constraint
        action_cost = self.costs[action]
        
        # FIXED: Enhanced budget penalty - harsher penalties for better budget discipline
        if self.current_cost + action_cost > self.C_max:
            # Calculate proportional penalty based on budget overrun
            overrun_amount = (self.current_cost + action_cost - self.C_max)
            overrun_ratio = overrun_amount / self.C_max
            
            # Penalty scales from base_penalty to max_penalty based on overrun
            penalty_scale = min(1.0, overrun_ratio)
            budget_penalty = -(self.config.base_budget_penalty + 
                             penalty_scale * (self.config.max_budget_penalty - self.config.base_budget_penalty))
            
            info = {
                "budget_exceeded": True,
                "current_cost": self.current_cost + action_cost,
                "overrun_amount": overrun_amount,
                "budget_penalty": budget_penalty
            }
            
            return self.current_skills.copy(), budget_penalty, True, False, info
        
        # Store previous skills for reward calculation
        prev_skills = self.current_skills.copy()
        
        # Apply training module
        self.current_skills = self._apply_training(self.current_skills, action)
        
        # Update cost and episode length
        self.current_cost += action_cost
        self.episode_length += 1
        
        # Check termination conditions
        terminated = (self.episode_length >= self.max_episode_length or 
                     self.current_cost >= self.C_max)
        
        # Calculate reward based on strategy
        reward = self._calculate_reward(prev_skills, self.current_skills, action_cost, terminated)
        
        info = {
            "current_cost": self.current_cost,
            "episode_length": self.episode_length,
            "skill_improvement": np.sum(self.current_skills - prev_skills),
            "total_skill_improvement": np.sum(self.current_skills - self.initial_skills),
            "budget_utilization": self.current_cost / self.C_max,
            "terminated": terminated,
            "budget_exceeded": False
        }
        
        return self.current_skills.copy(), reward, terminated, False, info
    
    def _apply_training(self, skills: np.ndarray, action: int) -> np.ndarray:
        """Apply training module to current skills."""
        new_skills = skills.copy()
        alpha_a = self.alpha[action]
        target_attributes = self.module_targets[action]
        
        # Calculate potential gains for each attribute
        for j in range(self.D):
            # Direct training effect
            if j in target_attributes:
                delta_j = (1 - skills[j]) ** self.kappa
            else:
                # Cross-attribute synergy effect
                delta_j = 0.0
                for k in target_attributes:
                    delta_j += self.synergy_matrix[j, k] * (1 - skills[j]) ** self.kappa
            
            # Apply training gain and forgetting
            new_skills[j] = skills[j] + alpha_a * delta_j - self.beta * skills[j]
        
        # Clip skills to valid range [0, 1]
        new_skills = np.clip(new_skills, 0.0, 1.0)
        
        return new_skills
    
    def _calculate_reward(self, prev_skills: np.ndarray, new_skills: np.ndarray, 
                         cost: float, terminated: bool) -> float:
        """Calculate reward with enhanced budget awareness."""
        skill_improvement = np.sum(new_skills - prev_skills)
        
        if self.config.reward_strategy == 'basic':
            # Basic: Amplified skill gain - increased cost penalty
            return (self.config.skill_amplifier * skill_improvement - 
                   self.config.cost_penalty * cost)
        
        elif self.config.reward_strategy == 'terminal':
            # Terminal: Small step rewards + large terminal bonus
            step_reward = skill_improvement - self.config.cost_penalty * cost
            
            if terminated and self.current_cost <= self.C_max:
                # Terminal bonus based on total skill level and budget efficiency
                total_skill_level = np.sum(self.current_skills)
                budget_efficiency = (self.C_max - self.current_cost) / self.C_max
                terminal_bonus = (total_skill_level * self.config.terminal_bonus_multiplier + 
                                budget_efficiency * 2.0)
                return step_reward + terminal_bonus
            
            return step_reward
        
        elif self.config.reward_strategy == 'efficiency':
            # Efficiency: Reward skill gains, bonus for finishing under budget
            step_reward = skill_improvement  # No cost penalty during episode
            
            if terminated:
                # End-of-episode rewards
                total_skills = np.sum(self.current_skills)
                if self.current_cost <= self.C_max:
                    budget_bonus = (self.C_max - self.current_cost) * 0.1
                    skill_bonus = total_skills * 1.5
                    return step_reward + budget_bonus + skill_bonus
                else:
                    return step_reward - 8.0  # Increased penalty for exceeding budget
            
            return step_reward
        
        elif self.config.reward_strategy == 'hybrid':
            # FIXED: Enhanced hybrid strategy with budget-aware terminal bonus
            base_reward = self.config.skill_amplifier * skill_improvement
            cost_penalty = self.config.cost_penalty * cost
            
            if terminated and self.current_cost <= self.C_max:
                # FIXED: Enhanced terminal bonus heavily favoring efficiency
                total_improvement = np.sum(self.current_skills - self.initial_skills)
                
                # Amplify efficiency bonus by 2x and keep improvement bonus the same
                efficiency_bonus = ((self.C_max - self.current_cost) / self.C_max) * 2.0  # 2x amplification
                improvement_bonus = total_improvement * 0.5  # Keep same
                
                terminal_bonus = improvement_bonus + efficiency_bonus
                return base_reward - cost_penalty + terminal_bonus
            
            return base_reward - cost_penalty
        
        else:
            raise ValueError(f"Unknown reward strategy: {self.config.reward_strategy}")
    
    def get_hierarchical_skills(self, skills: np.ndarray) -> Dict[str, float]:
        """Calculate hierarchical skill aggregations."""
        return {
            "technical_skills": np.mean(skills[0:4]),
            "soft_skills": np.mean(skills[4:8]),
            "coding_debugging": np.mean(skills[0:2]),
            "testing_architecture": np.mean(skills[2:4]),
            "communication_leadership": np.mean(skills[4:6]),
            "teamwork_problem_solving": np.mean(skills[6:8])
        }
    
    def render(self, mode: str = "human") -> None:
        """Render the current state."""
        if mode == "human":
            hierarchical = self.get_hierarchical_skills(self.current_skills)
            print(f"Episode Length: {self.episode_length}, Cost: {self.current_cost:.2f}/{self.C_max}")
            print("Hierarchical Skills:")
            for skill_name, value in hierarchical.items():
                print(f"  {skill_name}: {value:.3f}")
            print(f"Individual Skills: {self.current_skills}")


# =============================================================================
# ENHANCED NEURAL NETWORKS AND AGENT
# =============================================================================

class PolicyNetwork(nn.Module):
    """Enhanced policy network with better initialization and regularization."""
    
    def __init__(self, input_dim: int, hidden_dim: int, output_dim: int):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(0.1)
        
        # Better initialization
        self._init_weights()
        
    def _init_weights(self):
        """Initialize weights using Xavier initialization."""
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return F.softmax(x, dim=-1)


class ValueNetwork(nn.Module):
    """Enhanced value network with better initialization."""
    
    def __init__(self, input_dim: int, hidden_dim: int):
        super(ValueNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 1)
        self.dropout = nn.Dropout(0.1)
        
        # Better initialization
        self._init_weights()
        
    def _init_weights(self):
        """Initialize weights using Xavier initialization."""
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        return self.fc3(x)


class EnhancedREINFORCEAgent:
    """
    Enhanced REINFORCE agent with fixed learning rate scheduling.
    """
    
    def __init__(self, config: TrainingConfig):
        self.config = config
        self.state_dim = config.D
        self.action_dim = config.K
        self.use_baseline = config.use_baseline
        self.entropy_coefficient = config.entropy_coefficient
        
        # Policy network
        self.policy_net = PolicyNetwork(self.state_dim, config.hidden_dim, self.action_dim)
        self.policy_optimizer = optim.Adam(self.policy_net.parameters(), lr=config.learning_rate)
        
        # FIXED: Use StepLR instead of ExponentialLR for stable learning
        self.policy_scheduler = StepLR(
            self.policy_optimizer, 
            step_size=config.lr_step_size, 
            gamma=config.lr_gamma
        )
        
        # Value network (optional baseline)
        if self.use_baseline:
            self.value_net = ValueNetwork(self.state_dim, config.hidden_dim)
            self.value_optimizer = optim.Adam(self.value_net.parameters(), lr=config.learning_rate)
            self.value_scheduler = StepLR(
                self.value_optimizer, 
                step_size=config.lr_step_size, 
                gamma=config.lr_gamma
            )
        
        # Episode memory
        self.log_probs: List[torch.Tensor] = []
        self.rewards: List[float] = []
        self.states: List[torch.Tensor] = []
        self.entropies: List[torch.Tensor] = []  # For entropy regularization
        
        # Training statistics
        self.training_stats = {
            'policy_losses': [],
            'value_losses': [],
            'entropy_losses': [],
            'learning_rates': [],
            'lr_decay_steps': []  # Track when LR decays occur
        }
        
        print(f"Initialized budget-aware agent with LR={config.learning_rate}, "
              f"cost_penalty={config.cost_penalty}, step_size={config.lr_step_size}")
        
    def select_action(self, state: np.ndarray) -> int:
        """Select action using current policy and track entropy."""
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        action_probs = self.policy_net(state_tensor)
        
        # Sample action from probability distribution
        dist = Categorical(action_probs)
        action = dist.sample()
        
        # Store log probability, entropy, and state
        self.log_probs.append(dist.log_prob(action))
        self.entropies.append(dist.entropy())
        self.states.append(state_tensor)
        
        return action.item()
    
    def store_reward(self, reward: float) -> None:
        """Store reward for current step."""
        self.rewards.append(reward)
    
    def update_policy(self, gamma: float = 0.99) -> Dict[str, float]:
        """Enhanced policy update with improved learning rate tracking."""
        if len(self.rewards) == 0:
            return {"policy_loss": 0.0, "value_loss": 0.0, "entropy_loss": 0.0, "learning_rate": 0.0}
        
        # Store current learning rate before any updates
        current_lr = self.policy_optimizer.param_groups[0]['lr']
        
        # Calculate discounted returns
        returns = []
        R = 0
        for r in reversed(self.rewards):
            R = r + gamma * R
            returns.insert(0, R)
        
        returns = torch.tensor(returns, dtype=torch.float32)
        
        # Normalize returns for stability
        if len(returns) > 1:
            returns = (returns - returns.mean()) / (returns.std() + 1e-8)
        
        # Calculate policy loss components
        policy_losses = []
        value_losses = []
        entropy_losses = []
        
        for i, (log_prob, entropy, R) in enumerate(zip(self.log_probs, self.entropies, returns)):
            if self.use_baseline:
                # Use value function as baseline
                state = self.states[i]
                baseline = self.value_net(state).squeeze()
                advantage = R - baseline
                policy_losses.append(-log_prob * advantage.detach())
                value_losses.append(F.mse_loss(baseline, R))
            else:
                policy_losses.append(-log_prob * R)
            
            entropy_losses.append(entropy)
        
        # Combine losses
        policy_loss = torch.stack(policy_losses).mean()
        entropy_loss = torch.stack(entropy_losses).mean()
        
        # Total policy loss with entropy regularization
        total_policy_loss = policy_loss - self.entropy_coefficient * entropy_loss
        
        # Update policy network
        self.policy_optimizer.zero_grad()
        total_policy_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
        self.policy_optimizer.step()
        
        # Track LR decay steps
        prev_lr = current_lr
        self.policy_scheduler.step()
        new_lr = self.policy_optimizer.param_groups[0]['lr']
        
        if new_lr != prev_lr:
            self.training_stats['lr_decay_steps'].append(len(self.training_stats['learning_rates']))
        
        # Update value network if using baseline
        value_loss = torch.tensor(0.0)
        if self.use_baseline and value_losses:
            value_loss = torch.stack(value_losses).mean()
            
            self.value_optimizer.zero_grad()
            value_loss.backward()
            torch.nn.utils.clip_grad_norm_(self.value_net.parameters(), 1.0)
            self.value_optimizer.step()
            self.value_scheduler.step()
        
        # Store training statistics
        self.training_stats['policy_losses'].append(policy_loss.item())
        self.training_stats['value_losses'].append(value_loss.item())
        self.training_stats['entropy_losses'].append(entropy_loss.item())
        self.training_stats['learning_rates'].append(new_lr)
        
        # Clear episode memory
        self.log_probs.clear()
        self.rewards.clear()
        self.states.clear()
        self.entropies.clear()
        
        return {
            "policy_loss": policy_loss.item(),
            "value_loss": value_loss.item(),
            "entropy_loss": entropy_loss.item(),
            "learning_rate": new_lr
        }
    
    def get_state_value(self, state: np.ndarray) -> float:
        """Get state value estimate (if using baseline)."""
        if not self.use_baseline:
            return 0.0
        
        with torch.no_grad():
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            return self.value_net(state_tensor).item()
    
    def save_model(self, filepath: str) -> None:
        """Save trained model with training statistics."""
        os.makedirs(os.path.dirname(filepath), exist_ok=True)
        
        checkpoint = {
            'policy_net': self.policy_net.state_dict(),
            'policy_optimizer': self.policy_optimizer.state_dict(),
            'policy_scheduler': self.policy_scheduler.state_dict(),
            'config': self.config,
            'training_stats': self.training_stats
        }
        
        if self.use_baseline:
            checkpoint['value_net'] = self.value_net.state_dict()
            checkpoint['value_optimizer'] = self.value_optimizer.state_dict()
            checkpoint['value_scheduler'] = self.value_scheduler.state_dict()
        
        torch.save(checkpoint, filepath)
    
    def load_model(self, filepath: str) -> None:
        """Load trained model."""
        if not os.path.exists(filepath):
            print(f"Warning: Model file not found at {filepath}. Using random agent.")
            return
        
        checkpoint = torch.load(filepath)
        self.policy_net.load_state_dict(checkpoint['policy_net'])
        self.policy_optimizer.load_state_dict(checkpoint['policy_optimizer'])
        
        if 'policy_scheduler' in checkpoint:
            self.policy_scheduler.load_state_dict(checkpoint['policy_scheduler'])
        
        if self.use_baseline and 'value_net' in checkpoint:
            self.value_net.load_state_dict(checkpoint['value_net'])
            self.value_optimizer.load_state_dict(checkpoint['value_optimizer'])
            if 'value_scheduler' in checkpoint:
                self.value_scheduler.load_state_dict(checkpoint['value_scheduler'])
        
        if 'training_stats' in checkpoint:
            self.training_stats = checkpoint['training_stats']


# =============================================================================
# ENHANCED TRAINING LOOP
# =============================================================================

class EnhancedTrainingLoop:
    """Enhanced training loop with budget management focus."""
    
    def __init__(self, env: EmployeeTrainingEnv, agent: EnhancedREINFORCEAgent, config: TrainingConfig):
        self.env = env
        self.agent = agent
        self.config = config
        
        # Metrics tracking
        self.episode_rewards = []
        self.episode_lengths = []
        self.episode_costs = []
        self.policy_losses = []
        self.value_losses = []
        self.entropy_losses = []
        self.learning_rates = []
        self.skill_improvements = []
        self.budget_utilizations = []
        self.success_episodes = []
        self.budget_exceeded_episodes = []  # Track budget violations
        
        # Recent performance tracking
        self.recent_rewards = deque(maxlen=100)
        self.recent_lengths = deque(maxlen=100)
        self.recent_success = deque(maxlen=100)
        self.recent_entropy = deque(maxlen=100)  # Track entropy trend
        self.recent_budget_exceeded = deque(maxlen=100)  # Track budget discipline
        
        # Performance milestones
        self.first_positive_reward_episode = None
        self.first_80_percent_success = None
        self.first_budget_discipline = None  # NEW: When budget exceeded rate drops below 20%
        
    def run_episode(self) -> Dict[str, float]:
        """Run a single training episode with enhanced budget metrics."""
        state, _ = self.env.reset()
        episode_reward = 0
        episode_length = 0
        total_skill_improvement = 0
        budget_exceeded = False
        
        while True:
            # Select action
            action = self.agent.select_action(state)
            
            # Execute action
            next_state, reward, terminated, truncated, info = self.env.step(action)
            
            # Store reward
            self.agent.store_reward(reward)
            
            # Update metrics
            episode_reward += reward
            episode_length += 1
            total_skill_improvement += info.get('skill_improvement', 0)
            
            # Track budget exceeded
            if info.get('budget_exceeded', False):
                budget_exceeded = True
            
            # Update state
            state = next_state
            
            # Check termination
            if terminated or truncated:
                break
        
        # Update policy at end of episode
        losses = self.agent.update_policy(self.config.gamma)
        
        # Determine success (positive reward AND within budget)
        success = (episode_reward > 0 and not budget_exceeded)
        
        # Track milestones
        episode_num = len(self.episode_rewards) + 1
        if episode_reward > 0 and self.first_positive_reward_episode is None:
            self.first_positive_reward_episode = episode_num
            print(f"🎉 First positive reward achieved at episode {episode_num}!")
        
        return {
            'episode_reward': episode_reward,
            'episode_length': episode_length,
            'episode_cost': info.get('current_cost', 0),
            'skill_improvement': total_skill_improvement,
            'budget_utilization': info.get('budget_utilization', 0),
            'budget_exceeded': budget_exceeded,
            'success': success,
            'policy_loss': losses['policy_loss'],
            'value_loss': losses['value_loss'],
            'entropy_loss': losses['entropy_loss'],
            'learning_rate': losses['learning_rate']
        }
    
    def train(self) -> None:
        """Enhanced training loop with budget discipline tracking."""
        print("Starting Budget-Aware Training with Enhanced Cost Penalties...")
        print(f"Episodes: {self.config.num_episodes}")
        print(f"Environment: {self.env.D} skills, {self.env.K} training modules")
        print(f"Agent: {'Actor-Critic' if self.agent.use_baseline else 'REINFORCE'} with entropy regularization")
        print(f"Reward Strategy: {self.config.reward_strategy}")
        print(f"Learning Rate: {self.config.learning_rate} (StepLR: step={self.config.lr_step_size}, gamma={self.config.lr_gamma})")
        print(f"Cost Penalty: {self.config.cost_penalty} (5x increased for budget awareness)")
        print(f"Budget Penalties: base={self.config.base_budget_penalty}, max={self.config.max_budget_penalty}")
        print("-" * 90)
        
        start_time = time.time()
        best_avg_reward = float('-inf')
        episodes_since_improvement = 0
        
        for episode in range(self.config.num_episodes):
            # Run episode
            episode_metrics = self.run_episode()
            
            # Store metrics
            self.episode_rewards.append(episode_metrics['episode_reward'])
            self.episode_lengths.append(episode_metrics['episode_length'])
            self.episode_costs.append(episode_metrics['episode_cost'])
            self.skill_improvements.append(episode_metrics['skill_improvement'])
            self.budget_utilizations.append(episode_metrics['budget_utilization'])
            self.success_episodes.append(episode_metrics['success'])
            self.budget_exceeded_episodes.append(episode_metrics['budget_exceeded'])
            self.policy_losses.append(episode_metrics['policy_loss'])
            self.value_losses.append(episode_metrics['value_loss'])
            self.entropy_losses.append(episode_metrics['entropy_loss'])
            self.learning_rates.append(episode_metrics['learning_rate'])
            
            # Update recent performance
            self.recent_rewards.append(episode_metrics['episode_reward'])
            self.recent_lengths.append(episode_metrics['episode_length'])
            self.recent_success.append(episode_metrics['success'])
            self.recent_entropy.append(episode_metrics['entropy_loss'])
            self.recent_budget_exceeded.append(episode_metrics['budget_exceeded'])
            
            # Check for improvement and milestones
            if len(self.recent_rewards) >= 100:
                current_avg = np.mean(self.recent_rewards)
                current_success_rate = np.mean(self.recent_success)
                current_budget_exceeded_rate = np.mean(self.recent_budget_exceeded)
                
                if current_avg > best_avg_reward:
                    best_avg_reward = current_avg
                    episodes_since_improvement = 0
                else:
                    episodes_since_improvement += 1
                
                # Check for 80% success rate milestone
                if current_success_rate >= 0.8 and self.first_80_percent_success is None:
                    self.first_80_percent_success = episode + 1
                    print(f"🎯 80% success rate achieved at episode {episode + 1}!")
                
                # NEW: Check for budget discipline milestone
                if current_budget_exceeded_rate <= 0.2 and self.first_budget_discipline is None:
                    self.first_budget_discipline = episode + 1
                    print(f"💰 Budget discipline achieved (≤20% exceeded) at episode {episode + 1}!")
            
            # Logging with enhanced budget information
            if (episode + 1) % self.config.log_interval == 0:
                self._log_progress(episode + 1, episode_metrics)
            
            # Save model
            if (episode + 1) % self.config.save_interval == 0:
                self.agent.save_model(self.config.model_save_path)
                print(f"💾 Model saved at episode {episode + 1}")
        
        # Final save
        self.agent.save_model(self.config.model_save_path)
        
        # Training summary with budget focus
        training_time = time.time() - start_time
        final_success_rate = np.mean(self.recent_success) if len(self.recent_success) >= 10 else 0
        final_entropy = np.mean(self.recent_entropy) if len(self.recent_entropy) >= 10 else 0
        final_budget_exceeded_rate = np.mean(self.recent_budget_exceeded) if len(self.recent_budget_exceeded) >= 10 else 0
        
        print(f"\n{'='*90}")
        print("BUDGET-AWARE TRAINING COMPLETED")
        print(f"{'='*90}")
        print(f"Training time: {training_time:.2f} seconds")
        print(f"Best average reward (last 100): {best_avg_reward:.3f}")
        print(f"Final average reward (last 100): {np.mean(self.recent_rewards):.3f}")
        print(f"Final success rate (last 100): {final_success_rate:.2%}")
        print(f"Final budget exceeded rate (last 100): {final_budget_exceeded_rate:.2%} 🎯")
        print(f"Final entropy: {final_entropy:.3f} (max possible: {np.log(self.env.K):.3f})")
        print(f"Final learning rate: {self.learning_rates[-1]:.2e}")
        
        if self.first_positive_reward_episode:
            print(f"First positive reward: Episode {self.first_positive_reward_episode}")
        if self.first_80_percent_success:
            print(f"80% success milestone: Episode {self.first_80_percent_success}")
        if self.first_budget_discipline:
            print(f"Budget discipline milestone: Episode {self.first_budget_discipline}")
        
        # LR decay analysis
        lr_decays = len(self.agent.training_stats['lr_decay_steps'])
        print(f"Learning rate decayed {lr_decays} times during training")
        
    def _log_progress(self, episode: int, metrics: Dict[str, float]) -> None:
        """Enhanced progress logging with budget management focus."""
        avg_reward = np.mean(self.recent_rewards)
        avg_length = np.mean(self.recent_lengths)
        success_rate = np.mean(self.recent_success)
        avg_entropy = np.mean(self.recent_entropy)
        budget_exceeded_rate = np.mean(self.recent_budget_exceeded)
        
        # Trend indicators
        reward_trend = "📈" if len(self.recent_rewards) >= 50 and avg_reward > np.mean(list(self.recent_rewards)[:25]) else "📉"
        entropy_trend = "📉" if len(self.recent_entropy) >= 50 and avg_entropy < np.mean(list(self.recent_entropy)[:25]) else "📈"
        budget_trend = "📉" if len(self.recent_budget_exceeded) >= 50 and budget_exceeded_rate < np.mean(list(self.recent_budget_exceeded)[:25]) else "📈"
        
        print(f"Episode {episode:4d} | "
              f"Reward: {metrics['episode_reward']:6.2f} | "
              f"Avg: {avg_reward:6.2f} {reward_trend} | "
              f"Success: {success_rate:5.2%} | "
              f"Budget Exceeded: {budget_exceeded_rate:5.2%} {budget_trend} | "
              f"Entropy: {avg_entropy:5.3f} {entropy_trend} | "
              f"LR: {metrics['learning_rate']:.2e}")
    
    def evaluate(self, num_episodes: int = 100, render: bool = False) -> Dict[str, float]:
        """Enhanced evaluation with detailed budget analysis."""
        print(f"\nEvaluating budget-aware policy over {num_episodes} episodes...")
        
        eval_rewards = []
        eval_lengths = []
        eval_costs = []
        eval_skill_improvements = []
        eval_budget_utilizations = []
        eval_successes = []
        eval_budget_exceeded = []
        
        for episode in range(num_episodes):
            state, _ = self.env.reset()
            episode_reward = 0
            episode_length = 0
            total_skill_improvement = 0
            budget_exceeded = False
            
            while True:
                # Select action (deterministic for evaluation)
                with torch.no_grad():
                    state_tensor = torch.FloatTensor(state).unsqueeze(0)
                    action_probs = self.agent.policy_net(state_tensor)
                    action = torch.argmax(action_probs).item()
                
                next_state, reward, terminated, truncated, info = self.env.step(action)
                
                episode_reward += reward
                episode_length += 1
                total_skill_improvement += info.get('skill_improvement', 0)
                
                if info.get('budget_exceeded', False):
                    budget_exceeded = True
                
                if render and episode == 0:
                    self.env.render()
                
                state = next_state
                
                if terminated or truncated:
                    break
            
            eval_rewards.append(episode_reward)
            eval_lengths.append(episode_length)
            eval_costs.append(info.get('current_cost', 0))
            eval_skill_improvements.append(total_skill_improvement)
            eval_budget_utilizations.append(info.get('budget_utilization', 0))
            eval_successes.append(episode_reward > 0 and not budget_exceeded)
            eval_budget_exceeded.append(budget_exceeded)
        
        results = {
            'mean_reward': np.mean(eval_rewards),
            'std_reward': np.std(eval_rewards),
            'mean_length': np.mean(eval_lengths),
            'mean_cost': np.mean(eval_costs),
            'mean_skill_improvement': np.mean(eval_skill_improvements),
            'mean_budget_utilization': np.mean(eval_budget_utilizations),
            'success_rate': np.mean(eval_successes),
            'budget_exceeded_rate': np.mean(eval_budget_exceeded),
            'reward_improvement': np.mean(eval_rewards) - np.mean(self.episode_rewards[:100]) if len(self.episode_rewards) >= 100 else 0
        }
        
        print("Budget-Aware Evaluation Results:")
        print(f"  Mean Reward: {results['mean_reward']:.3f} ± {results['std_reward']:.3f}")
        print(f"  Mean Length: {results['mean_length']:.2f}")
        print(f"  Mean Cost: {results['mean_cost']:.2f}")
        print(f"  Mean Skill Improvement: {results['mean_skill_improvement']:.3f}")
        print(f"  Mean Budget Utilization: {results['mean_budget_utilization']:.2%}")
        print(f"  Success Rate: {results['success_rate']:.2%} 🎯")
        print(f"  Budget Exceeded Rate: {results['budget_exceeded_rate']:.2%} 💰")
        print(f"  Reward Improvement from Start: {results['reward_improvement']:+.3f}")
        
        return results
    
    def plot_enhanced_training_curves(self, save_path: str = None) -> None:
        """Enhanced training curves with budget management analysis."""
        fig, axes = plt.subplots(3, 3, figsize=(20, 15))
        
        # Episode rewards with milestone markers
        axes[0, 0].plot(self.episode_rewards, alpha=0.7, label='Raw')
        axes[0, 0].plot(self._smooth_curve(self.episode_rewards, 50), 'r-', linewidth=2, label='Smoothed')
        
        # Mark milestones
        if self.first_positive_reward_episode:
            axes[0, 0].axvline(self.first_positive_reward_episode, color='green', linestyle='--', 
                             label=f'First Positive ({self.first_positive_reward_episode})')
        if self.first_80_percent_success:
            axes[0, 0].axvline(self.first_80_percent_success, color='blue', linestyle='--',
                             label=f'80% Success ({self.first_80_percent_success})')
        if self.first_budget_discipline:
            axes[0, 0].axvline(self.first_budget_discipline, color='purple', linestyle='--',
                             label=f'Budget Discipline ({self.first_budget_discipline})')
        
        axes[0, 0].set_title('Episode Rewards with Budget Milestones')
        axes[0, 0].set_xlabel('Episode')
        axes[0, 0].set_ylabel('Reward')
        axes[0, 0].legend()
        axes[0, 0].grid(True)
        
        # Success rate with budget analysis
        success_rate = self._smooth_curve([int(s) for s in self.success_episodes], 50)
        budget_exceeded_rate = self._smooth_curve([int(b) for b in self.budget_exceeded_episodes], 50)
        axes[0, 1].plot(success_rate, 'g-', linewidth=2, label='Success Rate')
        axes[0, 1].plot(budget_exceeded_rate, 'r-', linewidth=2, label='Budget Exceeded Rate')
        axes[0, 1].axhline(0.2, color='orange', linestyle=':', label='Budget Discipline Target (20%)')
        axes[0, 1].set_title('Success vs Budget Management')
        axes[0, 1].set_xlabel('Episode')
        axes[0, 1].set_ylabel('Rate')
        axes[0, 1].legend()
        axes[0, 1].grid(True)
        
        # Learning rate with decay markers
        axes[0, 2].plot(self.learning_rates, 'b-', linewidth=2)
        # Mark LR decay steps
        for decay_step in self.agent.training_stats.get('lr_decay_steps', []):
            if decay_step < len(self.learning_rates):
                axes[0, 2].axvline(decay_step, color='red', linestyle=':', alpha=0.7)
        axes[0, 2].set_title('Learning Rate Schedule')
        axes[0, 2].set_xlabel('Episode')
        axes[0, 2].set_ylabel('Learning Rate')
        axes[0, 2].set_yscale('log')
        axes[0, 2].grid(True)
        
        # Entropy evolution
        axes[1, 0].plot(self.entropy_losses, alpha=0.7, label='Raw')
        axes[1, 0].plot(self._smooth_curve(self.entropy_losses, 50), 'r-', linewidth=2, label='Smoothed')
        axes[1, 0].axhline(np.log(self.env.K), color='black', linestyle='--', 
                          label=f'Max Entropy ({np.log(self.env.K):.3f})')
        axes[1, 0].set_title('Policy Entropy Evolution')
        axes[1, 0].set_xlabel('Episode')
        axes[1, 0].set_ylabel('Entropy')
        axes[1, 0].legend()
        axes[1, 0].grid(True)
        
        # Budget utilization with improved emphasis
        axes[1, 1].plot(self.budget_utilizations, alpha=0.7, label='Raw')
        axes[1, 1].plot(self._smooth_curve(self.budget_utilizations, 50), 'r-', linewidth=2, label='Smoothed')
        axes[1, 1].axhline(1.0, color='red', linestyle='--', linewidth=2, label='Budget Limit (100%)')
        axes[1, 1].axhline(0.8, color='orange', linestyle=':', label='Efficient Target (80%)')
        axes[1, 1].set_title('Budget Utilization (Key Metric)')
        axes[1, 1].set_xlabel('Episode')
        axes[1, 1].set_ylabel('Budget Used %')
        axes[1, 1].legend()
        axes[1, 1].grid(True)
        
        # Skill improvements
        axes[1, 2].plot(self.skill_improvements, alpha=0.7)
        axes[1, 2].plot(self._smooth_curve(self.skill_improvements, 50), 'r-', linewidth=2)
        axes[1, 2].set_title('Skill Improvements')
        axes[1, 2].set_xlabel('Episode')
        axes[1, 2].set_ylabel('Total Skill Δ')
        axes[1, 2].grid(True)
        
        # Policy and value losses
        axes[2, 0].plot(self.policy_losses, alpha=0.7)
        axes[2, 0].plot(self._smooth_curve(self.policy_losses, 50), 'r-', linewidth=2)
        axes[2, 0].set_title('Policy Losses')
        axes[2, 0].set_xlabel('Episode')
        axes[2, 0].set_ylabel('Loss')
        axes[2, 0].grid(True)
        
        if self.agent.use_baseline:
            axes[2, 1].plot(self.value_losses, alpha=0.7)
            axes[2, 1].plot(self._smooth_curve(self.value_losses, 50), 'r-', linewidth=2)
            axes[2, 1].set_title('Value Losses')
            axes[2, 1].set_xlabel('Episode')
            axes[2, 1].set_ylabel('Loss')
            axes[2, 1].grid(True)
        else:
            axes[2, 1].text(0.5, 0.5, 'No Baseline Used', ha='center', va='center', 
                           transform=axes[2, 1].transAxes, fontsize=14)
            axes[2, 1].set_title('Value Losses')
        
        # Budget management effectiveness
        budget_effectiveness = []
        for i in range(len(self.episode_rewards)):
            if i >= 99:  # Calculate over last 100 episodes
                recent_success = np.mean(self.success_episodes[i-99:i+1])
                recent_budget_ok = 1 - np.mean(self.budget_exceeded_episodes[i-99:i+1])
                effectiveness = (recent_success + recent_budget_ok) / 2  # Combined metric
                budget_effectiveness.append(effectiveness)
        
        if budget_effectiveness:
            axes[2, 2].plot(range(99, len(self.episode_rewards)), budget_effectiveness, 'g-', linewidth=2)
            axes[2, 2].axhline(0.8, color='blue', linestyle='--', label='Target (80%)')
            axes[2, 2].set_title('Budget Management Effectiveness')
            axes[2, 2].set_xlabel('Episode')
            axes[2, 2].set_ylabel('Effectiveness Score')
            axes[2, 2].legend()
            axes[2, 2].grid(True)
        
        plt.tight_layout()
        
        if save_path:
            plt.savefig(save_path, dpi=300, bbox_inches='tight')
            print(f"Budget-aware training curves saved to {save_path}")
        
        plt.show()
    
    def _smooth_curve(self, values: List[float], window: int = 50) -> List[float]:
        """Apply moving average smoothing to a curve."""
        if len(values) < window:
            return values
        
        smoothed = []
        for i in range(len(values)):
            start = max(0, i - window + 1)
            end = i + 1
            smoothed.append(np.mean(values[start:end]))
        
        return smoothed


# =============================================================================
# PERFORMANCE COMPARISON FRAMEWORK
# =============================================================================

class PerformanceComparison:
    """Framework for comparing budget-aware configurations."""
    
    def __init__(self, base_config: TrainingConfig):
        self.base_config = base_config
        self.results = {}
        
    def run_comparison(self, configurations: Dict[str, TrainingConfig], episodes: int = 1500) -> Dict:
        """Run training with different budget-aware configurations."""
        print("=== Budget-Aware Performance Comparison Framework ===")
        print(f"Testing {len(configurations)} configurations with {episodes} episodes each")
        print("Focus: Budget management and cost-effectiveness")
        print("=" * 70)
        
        results = {}
        
        for config_name, config in configurations.items():
            print(f"\nTesting Configuration: {config_name}")
            print(f"  Reward Strategy: {config.reward_strategy}")
            print(f"  Cost Penalty: {config.cost_penalty}")
            print(f"  Budget Penalties: base={config.base_budget_penalty}, max={config.max_budget_penalty}")
            print(f"  Entropy Coefficient: {config.entropy_coefficient}")
            print("-" * 50)
            
            # Update episodes for comparison
            config.num_episodes = episodes
            config.log_interval = max(episodes // 20, 25)
            
            # Create environment and agent
            env = EmployeeTrainingEnv(config)
            agent = EnhancedREINFORCEAgent(config)
            training_loop = EnhancedTrainingLoop(env, agent, config)
            
            # Train
            start_time = time.time()
            training_loop.train()
            training_time = time.time() - start_time
            
            # Evaluate
            eval_results = training_loop.evaluate(num_episodes=50, render=False)
            
            # Store results with budget-focused metrics
            results[config_name] = {
                'config': config,
                'training_time': training_time,
                'final_rewards': training_loop.episode_rewards[-100:],
                'final_success_rate': np.mean(training_loop.success_episodes[-100:]),
                'final_budget_exceeded_rate': np.mean(training_loop.budget_exceeded_episodes[-100:]),
                'final_entropy': np.mean(training_loop.entropy_losses[-100:]),
                'budget_discipline_episode': training_loop.first_budget_discipline,
                'eval_results': eval_results,
                'training_loop': training_loop
            }
            
            print(f"  Training Time: {training_time:.2f}s")
            print(f"  Final Success Rate: {eval_results['success_rate']:.2%}")
            print(f"  Final Budget Exceeded Rate: {eval_results['budget_exceeded_rate']:.2%}")
            print(f"  Final Mean Reward: {eval_results['mean_reward']:.3f}")
        
        self.results = results
        return results
    
    def print_summary(self) -> None:
        """Print budget-focused comparison summary."""
        if not self.results:
            print("No results to summarize. Run comparison first.")
            return
        
        print("\n" + "="*100)
        print("BUDGET-AWARE PERFORMANCE COMPARISON SUMMARY")
        print("="*100)
        
        # Sort by success rate (primary) and low budget exceeded rate (secondary)
        sorted_results = sorted(self.results.items(), 
                              key=lambda x: (x[1]['eval_results']['success_rate'], 
                                           -x[1]['eval_results']['budget_exceeded_rate']), 
                              reverse=True)
        
        # Header
        print(f"{'Rank':<4} {'Configuration':<20} {'Success Rate':<12} {'Budget Exceed':<12} "
              f"{'Mean Reward':<12} {'Budget Discipline':<16}")
        print("-" * 100)
        
        # Results
        for i, (config_name, result) in enumerate(sorted_results, 1):
            eval_results = result['eval_results']
            budget_discipline = result['budget_discipline_episode'] or "Not achieved"
            
            print(f"{i:<4} {config_name:<20} {eval_results['success_rate']:<12.2%} "
                  f"{eval_results['budget_exceeded_rate']:<12.2%} {eval_results['mean_reward']:<12.3f} "
                  f"{str(budget_discipline):<16}")
        
        print("\n" + "="*100)
        print("WINNER (Best Budget Management):", sorted_results[0][0])
        winner_config = sorted_results[0][1]['config']
        winner_result = sorted_results[0][1]
        
        print(f"  Reward Strategy: {winner_config.reward_strategy}")
        print(f"  Cost Penalty: {winner_config.cost_penalty}")
        print(f"  Budget Penalties: base={winner_config.base_budget_penalty}, max={winner_config.max_budget_penalty}")
        print(f"  Success Rate: {winner_result['eval_results']['success_rate']:.2%}")
        print(f"  Budget Exceeded Rate: {winner_result['eval_results']['budget_exceeded_rate']:.2%}")
        
        if winner_result['budget_discipline_episode']:
            print(f"  Budget Discipline Achieved: Episode {winner_result['budget_discipline_episode']}")


# =============================================================================
# MAIN EXECUTION AND UTILITIES
# =============================================================================

def create_directories():
    """Create necessary directories for saving models and plots."""
    os.makedirs('models', exist_ok=True)
    os.makedirs('plots', exist_ok=True)
    os.makedirs('logs', exist_ok=True)


def get_budget_aware_configurations() -> Dict[str, TrainingConfig]:
    """
    Get refined budget-aware configurations to find the optimal trade-off 
    between high reward and strict budget management.
    """
    
    # --- Base parameters that work well ---
    base_params = {
        'learning_rate': 3e-4,
        'entropy_coefficient': 0.001,
        'lr_step_size': 1500, # Give more time to learn before LR decay
        'lr_gamma': 0.9,
        'reward_strategy': 'hybrid' # This strategy has proven effective
    }

    # --- Create a modified config for the fast learner ---
    fast_learner_params = base_params.copy()
    fast_learner_params['learning_rate'] = 5e-4 # Override the learning rate here

    return {
        # Hypothesis: A balanced approach. A modest increase in cost penalty 
        # might be enough to improve budget discipline without hurting rewards too much.
        'balanced_approach': TrainingConfig(
            **base_params,
            cost_penalty=0.01, # 5x the original
            base_budget_penalty=4.0,
            max_budget_penalty=8.0
        ),

        # Hypothesis: Slightly more aggressive on cost. This is the configuration
        # recommended from the last analysis. It should further reduce budget overruns.
        'strong_incentive': TrainingConfig(
            **base_params,
            cost_penalty=0.015, # 7.5x the original
            base_budget_penalty=5.0,
            max_budget_penalty=10.0
        ),

        # Hypothesis: Very conservative. This agent should almost never exceed the budget.
        # The key question is: will it be too scared to take actions, resulting in low skill gain?
        'ultra_conservative': TrainingConfig(
            **base_params,
            cost_penalty=0.025, # Over 10x the original penalty
            base_budget_penalty=6.0,
            max_budget_penalty=12.0
        ),

        # Hypothesis: Focus on the terminal reward. Maybe a huge bonus for finishing
        # with budget to spare is a better signal than a punishing per-step cost.
        'terminal_focus_strong': TrainingConfig(
            reward_strategy='terminal',
            cost_penalty=0.008, # Lower step penalty, as the focus is on the end
            entropy_coefficient=0.001,
            learning_rate=3e-4,
            base_budget_penalty=5.0,
            max_budget_penalty=10.0,
            terminal_bonus_multiplier=3.5 # Greatly increased terminal bonus
        ),
        
        # FIXED: Unpack the modified dictionary to avoid the TypeError
        'fast_learner_frugal': TrainingConfig(
            **fast_learner_params, # Use the modified params
            cost_penalty=0.02,  # High cost penalty
            base_budget_penalty=5.0,
            max_budget_penalty=10.0
        )
    }


def main():
    """Budget-aware main entry point with enhanced cost management."""
    parser = argparse.ArgumentParser(description='Budget-Aware Employee Training Optimization')
    
    # --- Existing Arguments ---
    parser.add_argument('--mode', choices=['train', 'evaluate', 'visualize', 'compare'], 
                       default='train', help='Run mode')
    parser.add_argument('--model', type=str, help='Path to saved model for evaluation')
    parser.add_argument('--episodes', type=int, default=3000, help='Number of training episodes')
    parser.add_argument('--reward-strategy', choices=['basic', 'terminal', 'efficiency', 'hybrid'], 
                       default='hybrid', help='Reward strategy to use')
    parser.add_argument('--cost-penalty', type=float, default=0.01, help='Cost penalty coefficient')
    parser.add_argument('--entropy-coef', type=float, default=0.001, help='Entropy regularization coefficient')
    parser.add_argument('--learning-rate', type=float, default=3e-4, help='Learning rate')
    parser.add_argument('--lr-step-size', type=int, default=750, help='Learning rate decay step size')
    parser.add_argument('--lr-gamma', type=float, default=0.9, help='Learning rate decay factor')
    parser.add_argument('--no-baseline', action='store_true', help='Disable baseline (Actor-Critic)')
    parser.add_argument('--seed', type=int, default=42, help='Random seed')
    
    # --- FIXED: Add the missing arguments ---
    parser.add_argument('--base-budget-penalty', type=float, default=4.0, help='Base penalty for exceeding budget')
    parser.add_argument('--max-budget-penalty', type=float, default=8.0, help='Maximum penalty for exceeding budget')
    parser.add_argument('--terminal-bonus-multiplier', type=float, default=1.5, help='Multiplier for terminal bonus in reward function')

    args = parser.parse_args()
    
    # Set random seeds for reproducibility
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    
    # Create directories
    create_directories()
    
    print("Budget-Aware Employee Training Optimization System")
    print("=" * 80)
    print(f"Mode: {args.mode}")
    print(f"Seed: {args.seed}")
    print(f"User: Soumedhik")
    print("=" * 80)
    
    if args.mode == 'compare':
        # Performance comparison mode for budget-aware configurations
        print("Running performance comparison with budget-aware configurations...")
        
        base_config = TrainingConfig()
        comparison = PerformanceComparison(base_config)
        configurations = get_budget_aware_configurations()
        
        # Run the comparison
        results = comparison.run_comparison(configurations, episodes=args.episodes)
        
        # Summarize and present the results
        comparison.print_summary()
        
    else:
        # Create a single configuration for train, evaluate, or visualize modes
        # FIXED: Pass all the newly added arguments to the config
        config = TrainingConfig(
            num_episodes=args.episodes,
            reward_strategy=args.reward_strategy,
            cost_penalty=args.cost_penalty,
            entropy_coefficient=args.entropy_coef,
            learning_rate=args.learning_rate,
            lr_step_size=args.lr_step_size,
            lr_gamma=args.lr_gamma,
            use_baseline=not args.no_baseline,
            base_budget_penalty=args.base_budget_penalty,
            max_budget_penalty=args.max_budget_penalty,
            terminal_bonus_multiplier=args.terminal_bonus_multiplier
        )
        
        # Instantiate environment and agent
        env = EmployeeTrainingEnv(config)
        agent = EnhancedREINFORCEAgent(config)
        training_loop = EnhancedTrainingLoop(env, agent, config)
        
        print(f"Environment: {env.D} skills, {env.K} training modules")
        print(f"Agent: {'Enhanced Actor-Critic' if config.use_baseline else 'Enhanced REINFORCE'}")
        print(f"Reward Strategy: {config.reward_strategy}")
        print(f"Cost Penalty: {config.cost_penalty}")
        print(f"Learning Rate: {config.learning_rate} (StepLR: {config.lr_step_size}/{config.lr_gamma})")
        
        if args.mode == 'train':
            # Training mode
            print("\nStarting budget-aware training...")
            training_loop.train()
            
            # Plot the training curves
            training_loop.plot_enhanced_training_curves(
                save_path=os.path.join(config.plot_save_path, 'budget_aware_training_curves.png')
            )
            
            # Evaluate the newly trained model
            print("\nEvaluating trained model...")
            eval_results = training_loop.evaluate(
                num_episodes=config.eval_episodes,
                render=config.eval_render
            )
            
        elif args.mode == 'evaluate':
            # Evaluation mode
            if args.model:
                agent.load_model(args.model)
                print(f"Loaded model from {args.model}")
            else:
                print("Warning: No model specified for evaluation. Using a randomly initialized policy.")
            
            eval_results = training_loop.evaluate(
                num_episodes=config.eval_episodes,
                render=True
            )
            
        elif args.mode == 'visualize':
            # Visualization mode to inspect a trained agent's behavior
            if args.model:
                agent.load_model(args.model)
                print(f"Loaded model from {args.model}")
            else:
                print("Warning: No model specified for visualization. Using a randomly initialized policy.")

            print("\nGenerating visualizations for the agent's policy...")

            # --- 1. Visualize Skill Progression on Sample Episodes ---
            num_viz_episodes = 5
            skill_histories = []
            plt.figure(figsize=(12, 7))

            for i in range(num_viz_episodes):
                state, _ = env.reset()
                episode_skills = [state.copy()]
                
                while True:
                    with torch.no_grad():
                        action_probs = agent.policy_net(torch.FloatTensor(state).unsqueeze(0))
                        action = torch.argmax(action_probs).item()
                    
                    state, _, terminated, truncated, _ = env.step(action)
                    episode_skills.append(state.copy())

                    if terminated or truncated:
                        break
                
                skill_histories.append(np.array(episode_skills))

            # Plot average skill level over time for each sample episode
            for i, history in enumerate(skill_histories):
                avg_skill_per_step = np.mean(history, axis=1)
                plt.plot(avg_skill_per_step, alpha=0.8, label=f'Sample Run {i+1}')
            
            plt.title('Agent Policy: Average Skill Progression')
            plt.xlabel('Training Step in Episode')
            plt.ylabel('Average Skill Level')
            plt.legend()
            plt.grid(True)
            viz_path = os.path.join(config.plot_save_path, 'visualized_skill_progression.png')
            plt.savefig(viz_path, bbox_inches='tight')
            print(f"-> Skill progression plot saved to {viz_path}")
            plt.show()

            # --- 2. Visualize the Synergy Matrix ---
            plt.figure(figsize=(10, 8))
            skill_names = [
                'Coding', 'Debugging', 'Testing', 'Arch.',
                'Comm.', 'Leader.', 'Teamwork', 'Prob. Solv.'
            ]
            sns.heatmap(env.synergy_matrix, xticklabels=skill_names, yticklabels=skill_names,
                       annot=True, fmt='.2f', cmap='viridis', cbar_kws={'label': 'Synergy Coefficient'})
            plt.title('Environment: Cross-Attribute Synergy Matrix')
            synergy_path = os.path.join(config.plot_save_path, 'visualized_synergy_matrix.png')
            plt.savefig(synergy_path, bbox_inches='tight')
            print(f"-> Synergy matrix plot saved to {synergy_path}")
            plt.show()

            print("\nVisualizations generated and saved to 'plots/' directory.")

    print("\nEnhanced system execution completed.")

if __name__ == "__main__":
    main()
# Out:
# Writing single_file_rl_training_final.py

# %%
# !python single_file_rl_training_final.py --mode compare --episodes 100000
# Out:
# Budget-Aware Employee Training Optimization System
# ================================================================================
# Mode: compare
# Seed: 42
# User: Soumedhik
# ================================================================================
# Running performance comparison with budget-aware configurations...
# === Budget-Aware Performance Comparison Framework ===
# Testing 5 configurations with 100000 episodes each
# Focus: Budget management and cost-effectiveness
# ======================================================================
#
# Testing Configuration: balanced_approach
#   Reward Strategy: hybrid
#   Cost Penalty: 0.01
#   Budget Penalties: base=4.0, max=8.0
#   Entropy Coefficient: 0.001
# --------------------------------------------------
# Initialized budget-aware agent with LR=0.0003, cost_penalty=0.01, step_size=1500
# Starting Budget-Aware Training with Enhanced Cost Penalties...
# Episodes: 100000
# Environment: 8 skills, 4 training modules
# Agent: Actor-Critic with entropy regularization
# Reward Strategy: hybrid
# Learning Rate: 0.0003 (StepLR: step=1500, gamma=0.9)
# Cost Penalty: 0.01 (5x increased for budget awareness)
# Budget Penalties: base=4.0, max=8.0
# ------------------------------------------------------------------------------------------
# 🎉 First positive reward achieved at episode 9!
# 💾 Model saved at episode 500
# 💾 Model saved at episode 1000
# 💾 Model saved at episode 1500
# 💾 Model saved at episode 2000
# 💾 Model saved at episode 2500
# 💾 Model saved at episode 3000
# 💾 Model saved at episode 3500
# 💾 Model saved at episode 4000
# 💾 Model saved at episode 4500
# Episode 5000 | Reward:  -3.07 | Avg:  -0.84 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.596 📉 | LR: 2.19e-04
# 💾 Model saved at episode 5000
# 💾 Model saved at episode 5500
# 💾 Model saved at episode 6000
# 💾 Model saved at episode 6500
# 💾 Model saved at episode 7000
# 💾 Model saved at episode 7500
# 💾 Model saved at episode 8000
# 💾 Model saved at episode 8500
# 💾 Model saved at episode 9000
# 💾 Model saved at episode 9500
# Episode 10000 | Reward:   2.83 | Avg:   0.08 📈 | Success: 51.00% | Budget Exceeded: 49.00% 📉 | Entropy: 0.520 📈 | LR: 1.59e-04
# 💾 Model saved at episode 10000
# 💾 Model saved at episode 10500
# 💾 Model saved at episode 11000
# 💾 Model saved at episode 11500
# 💾 Model saved at episode 12000
# 💾 Model saved at episode 12500
# 💾 Model saved at episode 13000
# 💾 Model saved at episode 13500
# 💾 Model saved at episode 14000
# 💾 Model saved at episode 14500
# Episode 15000 | Reward:   2.57 | Avg:   0.17 📉 | Success: 52.00% | Budget Exceeded: 48.00% 📈 | Entropy: 0.442 📈 | LR: 1.05e-04
# 💾 Model saved at episode 15000
# 💾 Model saved at episode 15500
# 💾 Model saved at episode 16000
# 💾 Model saved at episode 16500
# 💾 Model saved at episode 17000
# 💾 Model saved at episode 17500
# 💾 Model saved at episode 18000
# 💾 Model saved at episode 18500
# 💾 Model saved at episode 19000
# 💾 Model saved at episode 19500
# Episode 20000 | Reward:   2.85 | Avg:  -0.20 📉 | Success: 45.00% | Budget Exceeded: 55.00% 📈 | Entropy: 0.420 📈 | LR: 7.63e-05
# 💾 Model saved at episode 20000
# 💾 Model saved at episode 20500
# 💾 Model saved at episode 21000
# 💾 Model saved at episode 21500
# 💾 Model saved at episode 22000
# 💾 Model saved at episode 22500
# 💾 Model saved at episode 23000
# 💾 Model saved at episode 23500
# 💾 Model saved at episode 24000
# 💾 Model saved at episode 24500
# Episode 25000 | Reward:   2.92 | Avg:   0.53 📉 | Success: 60.00% | Budget Exceeded: 40.00% 📈 | Entropy: 0.411 📈 | LR: 5.56e-05
# 💾 Model saved at episode 25000
# 💾 Model saved at episode 25500
# 💾 Model saved at episode 26000
# 💾 Model saved at episode 26500
# 💾 Model saved at episode 27000
# 💾 Model saved at episode 27500
# 💾 Model saved at episode 28000
# 💾 Model saved at episode 28500
# 💾 Model saved at episode 29000
# 💾 Model saved at episode 29500
# Episode 30000 | Reward:   2.35 | Avg:   0.81 📈 | Success: 64.00% | Budget Exceeded: 36.00% 📉 | Entropy: 0.395 📉 | LR: 3.65e-05
# 💾 Model saved at episode 30000
# 💾 Model saved at episode 30500
# 💾 Model saved at episode 31000
# 💾 Model saved at episode 31500
# 💾 Model saved at episode 32000
# 💾 Model saved at episode 32500
# 💾 Model saved at episode 33000
# 💾 Model saved at episode 33500
# 💾 Model saved at episode 34000
# 💾 Model saved at episode 34500
# Episode 35000 | Reward:   3.06 | Avg:   0.57 📈 | Success: 60.00% | Budget Exceeded: 40.00% 📉 | Entropy: 0.380 📈 | LR: 2.66e-05
# 💾 Model saved at episode 35000
# 💾 Model saved at episode 35500
# 💾 Model saved at episode 36000
# 💾 Model saved at episode 36500
# 💾 Model saved at episode 37000
# 💾 Model saved at episode 37500
# 💾 Model saved at episode 38000
# 💾 Model saved at episode 38500
# 💾 Model saved at episode 39000
# 💾 Model saved at episode 39500
# Episode 40000 | Reward:  -2.93 | Avg:   0.57 📉 | Success: 60.00% | Budget Exceeded: 40.00% 📈 | Entropy: 0.380 📉 | LR: 1.94e-05
# 💾 Model saved at episode 40000
# 💾 Model saved at episode 40500
# 💾 Model saved at episode 41000
# 💾 Model saved at episode 41500
# 💾 Model saved at episode 42000
# 💾 Model saved at episode 42500
# 💾 Model saved at episode 43000
# 💾 Model saved at episode 43500
# 💾 Model saved at episode 44000
# 💾 Model saved at episode 44500
# 🎯 80% success rate achieved at episode 44747!
# 💰 Budget discipline achieved (≤20% exceeded) at episode 44747!
# Episode 45000 | Reward:   2.56 | Avg:   0.35 📉 | Success: 57.00% | Budget Exceeded: 43.00% 📈 | Entropy: 0.381 📈 | LR: 1.27e-05
# 💾 Model saved at episode 45000
# 💾 Model saved at episode 45500
# 💾 Model saved at episode 46000
# 💾 Model saved at episode 46500
# 💾 Model saved at episode 47000
# 💾 Model saved at episode 47500
# 💾 Model saved at episode 48000
# 💾 Model saved at episode 48500
# 💾 Model saved at episode 49000
# 💾 Model saved at episode 49500
# Episode 50000 | Reward:  -3.00 | Avg:   0.47 📉 | Success: 59.00% | Budget Exceeded: 41.00% 📈 | Entropy: 0.373 📈 | LR: 9.27e-06
# 💾 Model saved at episode 50000
# 💾 Model saved at episode 50500
# 💾 Model saved at episode 51000
# 💾 Model saved at episode 51500
# 💾 Model saved at episode 52000
# 💾 Model saved at episode 52500
# 💾 Model saved at episode 53000
# 💾 Model saved at episode 53500
# 💾 Model saved at episode 54000
# 💾 Model saved at episode 54500
# Episode 55000 | Reward:  -2.59 | Avg:   0.73 📈 | Success: 63.00% | Budget Exceeded: 37.00% 📉 | Entropy: 0.367 📉 | LR: 6.76e-06
# 💾 Model saved at episode 55000
# 💾 Model saved at episode 55500
# 💾 Model saved at episode 56000
# 💾 Model saved at episode 56500
# 💾 Model saved at episode 57000
# 💾 Model saved at episode 57500
# 💾 Model saved at episode 58000
# 💾 Model saved at episode 58500
# 💾 Model saved at episode 59000
# 💾 Model saved at episode 59500
# Episode 60000 | Reward:   2.63 | Avg:   0.76 📈 | Success: 63.00% | Budget Exceeded: 37.00% 📉 | Entropy: 0.374 📉 | LR: 4.43e-06
# 💾 Model saved at episode 60000
# 💾 Model saved at episode 60500
# 💾 Model saved at episode 61000
# 💾 Model saved at episode 61500
# 💾 Model saved at episode 62000
# 💾 Model saved at episode 62500
# 💾 Model saved at episode 63000
# 💾 Model saved at episode 63500
# 💾 Model saved at episode 64000
# 💾 Model saved at episode 64500
# Episode 65000 | Reward:   2.91 | Avg:   0.85 📉 | Success: 64.00% | Budget Exceeded: 36.00% 📈 | Entropy: 0.365 📈 | LR: 3.23e-06
# 💾 Model saved at episode 65000
# 💾 Model saved at episode 65500
# 💾 Model saved at episode 66000
# 💾 Model saved at episode 66500
# 💾 Model saved at episode 67000
# 💾 Model saved at episode 67500
# 💾 Model saved at episode 68000
# 💾 Model saved at episode 68500
# 💾 Model saved at episode 69000
# 💾 Model saved at episode 69500
# Episode 70000 | Reward:   3.41 | Avg:   1.16 📈 | Success: 71.00% | Budget Exceeded: 29.00% 📉 | Entropy: 0.373 📉 | LR: 2.36e-06
# 💾 Model saved at episode 70000
# 💾 Model saved at episode 70500
# 💾 Model saved at episode 71000
# 💾 Model saved at episode 71500
# 💾 Model saved at episode 72000
# 💾 Model saved at episode 72500
# 💾 Model saved at episode 73000
# 💾 Model saved at episode 73500
# 💾 Model saved at episode 74000
# 💾 Model saved at episode 74500
# Episode 75000 | Reward:   3.25 | Avg:   0.32 📈 | Success: 55.00% | Budget Exceeded: 45.00% 📉 | Entropy: 0.371 📉 | LR: 1.55e-06
# 💾 Model saved at episode 75000
# 💾 Model saved at episode 75500
# 💾 Model saved at episode 76000
# 💾 Model saved at episode 76500
# 💾 Model saved at episode 77000
# 💾 Model saved at episode 77500
# 💾 Model saved at episode 78000
# 💾 Model saved at episode 78500
# 💾 Model saved at episode 79000
# 💾 Model saved at episode 79500
# Episode 80000 | Reward:   2.21 | Avg:   0.96 📈 | Success: 67.00% | Budget Exceeded: 33.00% 📈 | Entropy: 0.368 📉 | LR: 1.13e-06
# 💾 Model saved at episode 80000
# 💾 Model saved at episode 80500
# 💾 Model saved at episode 81000
# 💾 Model saved at episode 81500
# 💾 Model saved at episode 82000
# 💾 Model saved at episode 82500
# 💾 Model saved at episode 83000
# 💾 Model saved at episode 83500
# 💾 Model saved at episode 84000
# 💾 Model saved at episode 84500
# Episode 85000 | Reward:   2.73 | Avg:   0.76 📈 | Success: 64.00% | Budget Exceeded: 36.00% 📉 | Entropy: 0.365 📉 | LR: 8.22e-07
# 💾 Model saved at episode 85000
# 💾 Model saved at episode 85500
# 💾 Model saved at episode 86000
# 💾 Model saved at episode 86500
# 💾 Model saved at episode 87000
# 💾 Model saved at episode 87500
# 💾 Model saved at episode 88000
# 💾 Model saved at episode 88500
# 💾 Model saved at episode 89000
# 💾 Model saved at episode 89500
# Episode 90000 | Reward:   2.62 | Avg:   1.52 📈 | Success: 76.00% | Budget Exceeded: 24.00% 📉 | Entropy: 0.365 📉 | LR: 5.39e-07
# 💾 Model saved at episode 90000
# 💾 Model saved at episode 90500
# 💾 Model saved at episode 91000
# 💾 Model saved at episode 91500
# 💾 Model saved at episode 92000
# 💾 Model saved at episode 92500
# 💾 Model saved at episode 93000
# 💾 Model saved at episode 93500
# 💾 Model saved at episode 94000
# 💾 Model saved at episode 94500
# Episode 95000 | Reward:  -2.56 | Avg:   1.08 📈 | Success: 68.00% | Budget Exceeded: 32.00% 📉 | Entropy: 0.360 📉 | LR: 3.93e-07
# 💾 Model saved at episode 95000
# 💾 Model saved at episode 95500
# 💾 Model saved at episode 96000
# 💾 Model saved at episode 96500
# 💾 Model saved at episode 97000
# 💾 Model saved at episode 97500
# 💾 Model saved at episode 98000
# 💾 Model saved at episode 98500
# 💾 Model saved at episode 99000
# 💾 Model saved at episode 99500
# Episode 100000 | Reward:   2.93 | Avg:   0.46 📉 | Success: 58.00% | Budget Exceeded: 42.00% 📈 | Entropy: 0.369 📈 | LR: 2.87e-07
# 💾 Model saved at episode 100000
#
# ==========================================================================================
# BUDGET-AWARE TRAINING COMPLETED
# ==========================================================================================
# Training time: 2248.86 seconds
# Best average reward (last 100): 1.664
# Final average reward (last 100): 0.460
# Final success rate (last 100): 58.00%
# Final budget exceeded rate (last 100): 42.00% 🎯
# Final entropy: 0.369 (max possible: 1.386)
# Final learning rate: 2.87e-07
# First positive reward: Episode 9
# 80% success milestone: Episode 44747
# Budget discipline milestone: Episode 44747
# Learning rate decayed 66 times during training
#
# Evaluating budget-aware policy over 50 episodes...
# Budget-Aware Evaluation Results:
#   Mean Reward: 1.412 ± 2.554
#   Mean Length: 11.16
#   Mean Cost: 121.80
#   Mean Skill Improvement: 2.686
#   Mean Budget Utilization: 74.00%
#   Success Rate: 74.00% 🎯
#   Budget Exceeded Rate: 26.00% 💰
#   Reward Improvement from Start: +4.175
#   Training Time: 2248.86s
#   Final Success Rate: 74.00%
#   Final Budget Exceeded Rate: 26.00%
#   Final Mean Reward: 1.412
#
# Testing Configuration: strong_incentive
#   Reward Strategy: hybrid
#   Cost Penalty: 0.015
#   Budget Penalties: base=5.0, max=10.0
#   Entropy Coefficient: 0.001
# --------------------------------------------------
# Initialized budget-aware agent with LR=0.0003, cost_penalty=0.015, step_size=1500
# Starting Budget-Aware Training with Enhanced Cost Penalties...
# Episodes: 100000
# Environment: 8 skills, 4 training modules
# Agent: Actor-Critic with entropy regularization
# Reward Strategy: hybrid
# Learning Rate: 0.0003 (StepLR: step=1500, gamma=0.9)
# Cost Penalty: 0.015 (5x increased for budget awareness)
# Budget Penalties: base=5.0, max=10.0
# ------------------------------------------------------------------------------------------
# 🎉 First positive reward achieved at episode 2!
# 💾 Model saved at episode 500
# 💾 Model saved at episode 1000
# 💾 Model saved at episode 1500
# 💾 Model saved at episode 2000
# 💾 Model saved at episode 2500
# 💾 Model saved at episode 3000
# 💾 Model saved at episode 3500
# 💾 Model saved at episode 4000
# 💾 Model saved at episode 4500
# Episode 5000 | Reward:   2.58 | Avg:  -1.35 📈 | Success: 44.00% | Budget Exceeded: 56.00% 📉 | Entropy: 0.554 📉 | LR: 2.19e-04
# 💾 Model saved at episode 5000
# 💾 Model saved at episode 5500
# 💾 Model saved at episode 6000
# 💾 Model saved at episode 6500
# 💾 Model saved at episode 7000
# 💾 Model saved at episode 7500
# 💾 Model saved at episode 8000
# 💾 Model saved at episode 8500
# 💾 Model saved at episode 9000
# 💾 Model saved at episode 9500
# Episode 10000 | Reward:  -4.62 | Avg:  -0.26 📈 | Success: 62.00% | Budget Exceeded: 38.00% 📉 | Entropy: 0.440 📈 | LR: 1.59e-04
# 💾 Model saved at episode 10000
# 💾 Model saved at episode 10500
# 💾 Model saved at episode 11000
# 💾 Model saved at episode 11500
# 💾 Model saved at episode 12000
# 💾 Model saved at episode 12500
# 💾 Model saved at episode 13000
# 💾 Model saved at episode 13500
# 💾 Model saved at episode 14000
# 💾 Model saved at episode 14500
# Episode 15000 | Reward:   2.17 | Avg:  -0.48 📈 | Success: 59.00% | Budget Exceeded: 41.00% 📉 | Entropy: 0.414 📉 | LR: 1.05e-04
# 💾 Model saved at episode 15000
# 💾 Model saved at episode 15500
# 💾 Model saved at episode 16000
# 💾 Model saved at episode 16500
# 💾 Model saved at episode 17000
# 💾 Model saved at episode 17500
# 💾 Model saved at episode 18000
# 💾 Model saved at episode 18500
# 💾 Model saved at episode 19000
# 💾 Model saved at episode 19500
# Episode 20000 | Reward:  -4.12 | Avg:  -0.48 📉 | Success: 59.00% | Budget Exceeded: 41.00% 📈 | Entropy: 0.350 📈 | LR: 7.63e-05
# 💾 Model saved at episode 20000
# 💾 Model saved at episode 20500
# 💾 Model saved at episode 21000
# 💾 Model saved at episode 21500
# 💾 Model saved at episode 22000
# 💾 Model saved at episode 22500
# 💾 Model saved at episode 23000
# 💾 Model saved at episode 23500
# 💾 Model saved at episode 24000
# 💾 Model saved at episode 24500
# Episode 25000 | Reward:  -4.03 | Avg:   0.35 📉 | Success: 71.00% | Budget Exceeded: 29.00% 📈 | Entropy: 0.333 📉 | LR: 5.56e-05
# 💾 Model saved at episode 25000
# 💾 Model saved at episode 25500
# 💾 Model saved at episode 26000
# 💾 Model saved at episode 26500
# 💾 Model saved at episode 27000
# 💾 Model saved at episode 27500
# 💾 Model saved at episode 28000
# 💾 Model saved at episode 28500
# 💾 Model saved at episode 29000
# 🎯 80% success rate achieved at episode 29235!
# 💰 Budget discipline achieved (≤20% exceeded) at episode 29235!
# 💾 Model saved at episode 29500
# Episode 30000 | Reward:   1.75 | Avg:   0.43 📉 | Success: 74.00% | Budget Exceeded: 26.00% 📈 | Entropy: 0.314 📉 | LR: 3.65e-05
# 💾 Model saved at episode 30000
# 💾 Model saved at episode 30500
# 💾 Model saved at episode 31000
# 💾 Model saved at episode 31500
# 💾 Model saved at episode 32000
# 💾 Model saved at episode 32500
# 💾 Model saved at episode 33000
# 💾 Model saved at episode 33500
# 💾 Model saved at episode 34000
# 💾 Model saved at episode 34500
# Episode 35000 | Reward:   2.19 | Avg:   0.06 📈 | Success: 67.00% | Budget Exceeded: 33.00% 📉 | Entropy: 0.307 📈 | LR: 2.66e-05
# 💾 Model saved at episode 35000
# 💾 Model saved at episode 35500
# 💾 Model saved at episode 36000
# 💾 Model saved at episode 36500
# 💾 Model saved at episode 37000
# 💾 Model saved at episode 37500
# 💾 Model saved at episode 38000
# 💾 Model saved at episode 38500
# 💾 Model saved at episode 39000
# 💾 Model saved at episode 39500
# Episode 40000 | Reward:   2.61 | Avg:   0.81 📈 | Success: 79.00% | Budget Exceeded: 21.00% 📉 | Entropy: 0.308 📈 | LR: 1.94e-05
# 💾 Model saved at episode 40000
# 💾 Model saved at episode 40500
# 💾 Model saved at episode 41000
# 💾 Model saved at episode 41500
# 💾 Model saved at episode 42000
# 💾 Model saved at episode 42500
# 💾 Model saved at episode 43000
# 💾 Model saved at episode 43500
# 💾 Model saved at episode 44000
# 💾 Model saved at episode 44500
# Episode 45000 | Reward:  -4.26 | Avg:   0.26 📈 | Success: 70.00% | Budget Exceeded: 30.00% 📉 | Entropy: 0.287 📈 | LR: 1.27e-05
# 💾 Model saved at episode 45000
# 💾 Model saved at episode 45500
# 💾 Model saved at episode 46000
# 💾 Model saved at episode 46500
# 💾 Model saved at episode 47000
# 💾 Model saved at episode 47500
# 💾 Model saved at episode 48000
# 💾 Model saved at episode 48500
# 💾 Model saved at episode 49000
# 💾 Model saved at episode 49500
# Episode 50000 | Reward:   1.50 | Avg:   0.23 📉 | Success: 70.00% | Budget Exceeded: 30.00% 📈 | Entropy: 0.286 📉 | LR: 9.27e-06
# 💾 Model saved at episode 50000
# 💾 Model saved at episode 50500
# 💾 Model saved at episode 51000
# 💾 Model saved at episode 51500
# 💾 Model saved at episode 52000
# 💾 Model saved at episode 52500
# 💾 Model saved at episode 53000
# 💾 Model saved at episode 53500
# 💾 Model saved at episode 54000
# 💾 Model saved at episode 54500
# Episode 55000 | Reward:  -4.85 | Avg:   0.24 📈 | Success: 70.00% | Budget Exceeded: 30.00% 📉 | Entropy: 0.288 📉 | LR: 6.76e-06
# 💾 Model saved at episode 55000
# 💾 Model saved at episode 55500
# 💾 Model saved at episode 56000
# 💾 Model saved at episode 56500
# 💾 Model saved at episode 57000
# 💾 Model saved at episode 57500
# 💾 Model saved at episode 58000
# 💾 Model saved at episode 58500
# 💾 Model saved at episode 59000
# 💾 Model saved at episode 59500
# Episode 60000 | Reward:   2.76 | Avg:  -0.02 📉 | Success: 67.00% | Budget Exceeded: 33.00% 📈 | Entropy: 0.290 📈 | LR: 4.43e-06
# 💾 Model saved at episode 60000
# 💾 Model saved at episode 60500
# 💾 Model saved at episode 61000
# 💾 Model saved at episode 61500
# 💾 Model saved at episode 62000
# 💾 Model saved at episode 62500
# 💾 Model saved at episode 63000
# 💾 Model saved at episode 63500
# 💾 Model saved at episode 64000
# 💾 Model saved at episode 64500
# Episode 65000 | Reward:   2.02 | Avg:   0.42 📈 | Success: 73.00% | Budget Exceeded: 27.00% 📉 | Entropy: 0.279 📉 | LR: 3.23e-06
# 💾 Model saved at episode 65000
# 💾 Model saved at episode 65500
# 💾 Model saved at episode 66000
# 💾 Model saved at episode 66500
# 💾 Model saved at episode 67000
# 💾 Model saved at episode 67500
# 💾 Model saved at episode 68000
# 💾 Model saved at episode 68500
# 💾 Model saved at episode 69000
# 💾 Model saved at episode 69500
# Episode 70000 | Reward:   2.76 | Avg:   0.21 📉 | Success: 68.00% | Budget Exceeded: 32.00% 📈 | Entropy: 0.281 📉 | LR: 2.36e-06
# 💾 Model saved at episode 70000
# 💾 Model saved at episode 70500
# 💾 Model saved at episode 71000
# 💾 Model saved at episode 71500
# 💾 Model saved at episode 72000
# 💾 Model saved at episode 72500
# 💾 Model saved at episode 73000
# 💾 Model saved at episode 73500
# 💾 Model saved at episode 74000
# 💾 Model saved at episode 74500
# Episode 75000 | Reward:   2.29 | Avg:   0.25 📉 | Success: 70.00% | Budget Exceeded: 30.00% 📈 | Entropy: 0.283 📉 | LR: 1.55e-06
# 💾 Model saved at episode 75000
# 💾 Model saved at episode 75500
# 💾 Model saved at episode 76000
# 💾 Model saved at episode 76500
# 💾 Model saved at episode 77000
# 💾 Model saved at episode 77500
# 💾 Model saved at episode 78000
# 💾 Model saved at episode 78500
# 💾 Model saved at episode 79000
# 💾 Model saved at episode 79500
# Episode 80000 | Reward:   1.58 | Avg:   0.69 📉 | Success: 77.00% | Budget Exceeded: 23.00% 📈 | Entropy: 0.284 📉 | LR: 1.13e-06
# 💾 Model saved at episode 80000
# 💾 Model saved at episode 80500
# 💾 Model saved at episode 81000
# 💾 Model saved at episode 81500
# 💾 Model saved at episode 82000
# 💾 Model saved at episode 82500
# 💾 Model saved at episode 83000
# 💾 Model saved at episode 83500
# 💾 Model saved at episode 84000
# 💾 Model saved at episode 84500
# Episode 85000 | Reward:   2.58 | Avg:   0.28 📈 | Success: 70.00% | Budget Exceeded: 30.00% 📉 | Entropy: 0.268 📉 | LR: 8.22e-07
# 💾 Model saved at episode 85000
# 💾 Model saved at episode 85500
# 💾 Model saved at episode 86000
# 💾 Model saved at episode 86500
# 💾 Model saved at episode 87000
# 💾 Model saved at episode 87500
# 💾 Model saved at episode 88000
# 💾 Model saved at episode 88500
# 💾 Model saved at episode 89000
# 💾 Model saved at episode 89500
# Episode 90000 | Reward:   2.13 | Avg:   0.43 📈 | Success: 73.00% | Budget Exceeded: 27.00% 📉 | Entropy: 0.278 📉 | LR: 5.39e-07
# 💾 Model saved at episode 90000
# 💾 Model saved at episode 90500
# 💾 Model saved at episode 91000
# 💾 Model saved at episode 91500
# 💾 Model saved at episode 92000
# 💾 Model saved at episode 92500
# 💾 Model saved at episode 93000
# 💾 Model saved at episode 93500
# 💾 Model saved at episode 94000
# 💾 Model saved at episode 94500
# Episode 95000 | Reward:   2.70 | Avg:   0.68 📈 | Success: 77.00% | Budget Exceeded: 23.00% 📉 | Entropy: 0.275 📈 | LR: 3.93e-07
# 💾 Model saved at episode 95000
# 💾 Model saved at episode 95500
# 💾 Model saved at episode 96000
# 💾 Model saved at episode 96500
# 💾 Model saved at episode 97000
# 💾 Model saved at episode 97500
# 💾 Model saved at episode 98000
# 💾 Model saved at episode 98500
# 💾 Model saved at episode 99000
# 💾 Model saved at episode 99500
# Episode 100000 | Reward:  -4.13 | Avg:  -0.25 📉 | Success: 63.00% | Budget Exceeded: 37.00% 📈 | Entropy: 0.272 📈 | LR: 2.87e-07
# 💾 Model saved at episode 100000
#
# ==========================================================================================
# BUDGET-AWARE TRAINING COMPLETED
# ==========================================================================================
# Training time: 2189.31 seconds
# Best average reward (last 100): 1.310
# Final average reward (last 100): -0.250
# Final success rate (last 100): 63.00%
# Final budget exceeded rate (last 100): 37.00% 🎯
# Final entropy: 0.272 (max possible: 1.386)
# Final learning rate: 2.87e-07
# First positive reward: Episode 2
# 80% success milestone: Episode 29235
# Budget discipline milestone: Episode 29235
# Learning rate decayed 66 times during training
#
# Evaluating budget-aware policy over 50 episodes...
# Budget-Aware Evaluation Results:
#   Mean Reward: 0.447 ± 2.821
#   Mean Length: 11.18
#   Mean Cost: 121.88
#   Mean Skill Improvement: 2.545
#   Mean Budget Utilization: 76.00%
#   Success Rate: 76.00% 🎯
#   Budget Exceeded Rate: 24.00% 💰
#   Reward Improvement from Start: +4.681
#   Training Time: 2189.31s
#   Final Success Rate: 76.00%
#   Final Budget Exceeded Rate: 24.00%
#   Final Mean Reward: 0.447
#
# Testing Configuration: ultra_conservative
#   Reward Strategy: hybrid
#   Cost Penalty: 0.025
#   Budget Penalties: base=6.0, max=12.0
#   Entropy Coefficient: 0.001
# --------------------------------------------------
# Initialized budget-aware agent with LR=0.0003, cost_penalty=0.025, step_size=1500
# Starting Budget-Aware Training with Enhanced Cost Penalties...
# Episodes: 100000
# Environment: 8 skills, 4 training modules
# Agent: Actor-Critic with entropy regularization
# Reward Strategy: hybrid
# Learning Rate: 0.0003 (StepLR: step=1500, gamma=0.9)
# Cost Penalty: 0.025 (5x increased for budget awareness)
# Budget Penalties: base=6.0, max=12.0
# ------------------------------------------------------------------------------------------
# 🎉 First positive reward achieved at episode 60!
# 💾 Model saved at episode 500
# 💾 Model saved at episode 1000
# 💾 Model saved at episode 1500
# 💾 Model saved at episode 2000
# 💾 Model saved at episode 2500
# 💾 Model saved at episode 3000
# 💾 Model saved at episode 3500
# 💾 Model saved at episode 4000
# 💾 Model saved at episode 4500
# Episode 5000 | Reward:  -6.90 | Avg:  -2.76 📈 | Success: 50.00% | Budget Exceeded: 50.00% 📉 | Entropy: 0.535 📈 | LR: 2.19e-04
# 💾 Model saved at episode 5000
# 💾 Model saved at episode 5500
# 💾 Model saved at episode 6000
# 💾 Model saved at episode 6500
# 💾 Model saved at episode 7000
# 💾 Model saved at episode 7500
# 💾 Model saved at episode 8000
# 💾 Model saved at episode 8500
# 💾 Model saved at episode 9000
# 💾 Model saved at episode 9500
# Episode 10000 | Reward:  -0.22 | Avg:  -2.06 📉 | Success: 56.00% | Budget Exceeded: 41.00% 📈 | Entropy: 0.485 📈 | LR: 1.59e-04
# 💾 Model saved at episode 10000
# 💾 Model saved at episode 10500
# 💾 Model saved at episode 11000
# 💾 Model saved at episode 11500
# 💾 Model saved at episode 12000
# 💾 Model saved at episode 12500
# 💾 Model saved at episode 13000
# 💾 Model saved at episode 13500
# 💾 Model saved at episode 14000
# 💾 Model saved at episode 14500
# Episode 15000 | Reward:  -5.93 | Avg:  -2.32 📉 | Success: 56.00% | Budget Exceeded: 44.00% 📈 | Entropy: 0.420 📈 | LR: 1.05e-04
# 💾 Model saved at episode 15000
# 💾 Model saved at episode 15500
# 💾 Model saved at episode 16000
# 💾 Model saved at episode 16500
# 💾 Model saved at episode 17000
# 💾 Model saved at episode 17500
# 💾 Model saved at episode 18000
# 💾 Model saved at episode 18500
# 💾 Model saved at episode 19000
# 💾 Model saved at episode 19500
# Episode 20000 | Reward:   1.17 | Avg:  -1.51 📈 | Success: 66.00% | Budget Exceeded: 34.00% 📉 | Entropy: 0.366 📉 | LR: 7.63e-05
# 💾 Model saved at episode 20000
# 💾 Model saved at episode 20500
# 💾 Model saved at episode 21000
# 💾 Model saved at episode 21500
# 💾 Model saved at episode 22000
# 💾 Model saved at episode 22500
# 💾 Model saved at episode 23000
# 💾 Model saved at episode 23500
# 💾 Model saved at episode 24000
# 💾 Model saved at episode 24500
# Episode 25000 | Reward:   1.41 | Avg:  -2.25 📈 | Success: 54.00% | Budget Exceeded: 44.00% 📉 | Entropy: 0.403 📈 | LR: 5.56e-05
# 💾 Model saved at episode 25000
# 💾 Model saved at episode 25500
# 💾 Model saved at episode 26000
# 💾 Model saved at episode 26500
# 💾 Model saved at episode 27000
# 💾 Model saved at episode 27500
# 💾 Model saved at episode 28000
# 💾 Model saved at episode 28500
# 💾 Model saved at episode 29000
# 💾 Model saved at episode 29500
# Episode 30000 | Reward:  -6.40 | Avg:  -2.51 📉 | Success: 53.00% | Budget Exceeded: 47.00% 📈 | Entropy: 0.419 📈 | LR: 3.65e-05
# 💾 Model saved at episode 30000
# 💾 Model saved at episode 30500
# 💾 Model saved at episode 31000
# 💾 Model saved at episode 31500
# 💾 Model saved at episode 32000
# 💾 Model saved at episode 32500
# 💾 Model saved at episode 33000
# 💾 Model saved at episode 33500
# 💾 Model saved at episode 34000
# 💾 Model saved at episode 34500
# Episode 35000 | Reward:   0.68 | Avg:  -2.82 📈 | Success: 49.00% | Budget Exceeded: 51.00% 📉 | Entropy: 0.423 📈 | LR: 2.66e-05
# 💾 Model saved at episode 35000
# 💾 Model saved at episode 35500
# 💾 Model saved at episode 36000
# 💾 Model saved at episode 36500
# 💾 Model saved at episode 37000
# 💾 Model saved at episode 37500
# 💾 Model saved at episode 38000
# 💾 Model saved at episode 38500
# 💾 Model saved at episode 39000
# 💾 Model saved at episode 39500
# Episode 40000 | Reward:   0.94 | Avg:  -3.37 📉 | Success: 41.00% | Budget Exceeded: 58.00% 📈 | Entropy: 0.439 📉 | LR: 1.94e-05
# 💾 Model saved at episode 40000
# 💾 Model saved at episode 40500
# 💾 Model saved at episode 41000
# 💾 Model saved at episode 41500
# 💾 Model saved at episode 42000
# 💾 Model saved at episode 42500
# 💾 Model saved at episode 43000
# 💾 Model saved at episode 43500
# 💾 Model saved at episode 44000
# 💾 Model saved at episode 44500
# Episode 45000 | Reward:   1.37 | Avg:  -3.08 📉 | Success: 45.00% | Budget Exceeded: 54.00% 📈 | Entropy: 0.420 📉 | LR: 1.27e-05
# 💾 Model saved at episode 45000
# 💾 Model saved at episode 45500
# 💾 Model saved at episode 46000
# 💾 Model saved at episode 46500
# 💾 Model saved at episode 47000
# 💾 Model saved at episode 47500
# 💾 Model saved at episode 48000
# 💾 Model saved at episode 48500
# 💾 Model saved at episode 49000
# 💾 Model saved at episode 49500
# Episode 50000 | Reward:  -6.55 | Avg:  -3.32 📉 | Success: 42.00% | Budget Exceeded: 58.00% 📈 | Entropy: 0.446 📉 | LR: 9.27e-06
# 💾 Model saved at episode 50000
# 💾 Model saved at episode 50500
# 💾 Model saved at episode 51000
# 💾 Model saved at episode 51500
# 💾 Model saved at episode 52000
# 💾 Model saved at episode 52500
# 💾 Model saved at episode 53000
# 💾 Model saved at episode 53500
# 💾 Model saved at episode 54000
# 💾 Model saved at episode 54500
# Episode 55000 | Reward:  -5.85 | Avg:  -2.72 📈 | Success: 50.00% | Budget Exceeded: 50.00% 📉 | Entropy: 0.431 📉 | LR: 6.76e-06
# 💾 Model saved at episode 55000
# 💾 Model saved at episode 55500
# 💾 Model saved at episode 56000
# 💾 Model saved at episode 56500
# 💾 Model saved at episode 57000
# 💾 Model saved at episode 57500
# 💾 Model saved at episode 58000
# 💾 Model saved at episode 58500
# 💾 Model saved at episode 59000
# 💾 Model saved at episode 59500
# Episode 60000 | Reward:  -6.47 | Avg:  -3.51 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.430 📈 | LR: 4.43e-06
# 💾 Model saved at episode 60000
# 💾 Model saved at episode 60500
# 💾 Model saved at episode 61000
# 💾 Model saved at episode 61500
# 💾 Model saved at episode 62000
# 💾 Model saved at episode 62500
# 💾 Model saved at episode 63000
# 💾 Model saved at episode 63500
# 💾 Model saved at episode 64000
# 💾 Model saved at episode 64500
# Episode 65000 | Reward:  -6.50 | Avg:  -2.41 📈 | Success: 55.00% | Budget Exceeded: 45.00% 📉 | Entropy: 0.424 📉 | LR: 3.23e-06
# 💾 Model saved at episode 65000
# 💾 Model saved at episode 65500
# 💾 Model saved at episode 66000
# 💾 Model saved at episode 66500
# 💾 Model saved at episode 67000
# 💾 Model saved at episode 67500
# 💾 Model saved at episode 68000
# 💾 Model saved at episode 68500
# 💾 Model saved at episode 69000
# 💾 Model saved at episode 69500
# Episode 70000 | Reward:  -6.41 | Avg:  -3.25 📈 | Success: 43.00% | Budget Exceeded: 57.00% 📉 | Entropy: 0.430 📉 | LR: 2.36e-06
# 💾 Model saved at episode 70000
# 💾 Model saved at episode 70500
# 💾 Model saved at episode 71000
# 💾 Model saved at episode 71500
# 💾 Model saved at episode 72000
# 💾 Model saved at episode 72500
# 💾 Model saved at episode 73000
# 💾 Model saved at episode 73500
# 💾 Model saved at episode 74000
# 💾 Model saved at episode 74500
# Episode 75000 | Reward:   1.35 | Avg:  -2.68 📉 | Success: 51.00% | Budget Exceeded: 49.00% 📈 | Entropy: 0.442 📉 | LR: 1.55e-06
# 💾 Model saved at episode 75000
# 💾 Model saved at episode 75500
# 💾 Model saved at episode 76000
# 💾 Model saved at episode 76500
# 💾 Model saved at episode 77000
# 💾 Model saved at episode 77500
# 💾 Model saved at episode 78000
# 💾 Model saved at episode 78500
# 💾 Model saved at episode 79000
# 💾 Model saved at episode 79500
# Episode 80000 | Reward:  -6.30 | Avg:  -3.87 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.452 📈 | LR: 1.13e-06
# 💾 Model saved at episode 80000
# 💾 Model saved at episode 80500
# 💾 Model saved at episode 81000
# 💾 Model saved at episode 81500
# 💾 Model saved at episode 82000
# 💾 Model saved at episode 82500
# 💾 Model saved at episode 83000
# 💾 Model saved at episode 83500
# 💾 Model saved at episode 84000
# 💾 Model saved at episode 84500
# Episode 85000 | Reward:  -6.69 | Avg:  -3.15 📉 | Success: 43.00% | Budget Exceeded: 56.00% 📈 | Entropy: 0.444 📈 | LR: 8.22e-07
# 💾 Model saved at episode 85000
# 💾 Model saved at episode 85500
# 💾 Model saved at episode 86000
# 💾 Model saved at episode 86500
# 💾 Model saved at episode 87000
# 💾 Model saved at episode 87500
# 💾 Model saved at episode 88000
# 💾 Model saved at episode 88500
# 💾 Model saved at episode 89000
# 💾 Model saved at episode 89500
# Episode 90000 | Reward:  -6.32 | Avg:  -2.50 📉 | Success: 53.00% | Budget Exceeded: 47.00% 📈 | Entropy: 0.441 📉 | LR: 5.39e-07
# 💾 Model saved at episode 90000
# 💾 Model saved at episode 90500
# 💾 Model saved at episode 91000
# 💾 Model saved at episode 91500
# 💾 Model saved at episode 92000
# 💾 Model saved at episode 92500
# 💾 Model saved at episode 93000
# 💾 Model saved at episode 93500
# 💾 Model saved at episode 94000
# 💾 Model saved at episode 94500
# Episode 95000 | Reward:  -7.23 | Avg:  -3.40 📉 | Success: 40.00% | Budget Exceeded: 59.00% 📈 | Entropy: 0.446 📈 | LR: 3.93e-07
# 💾 Model saved at episode 95000
# 💾 Model saved at episode 95500
# 💾 Model saved at episode 96000
# 💾 Model saved at episode 96500
# 💾 Model saved at episode 97000
# 💾 Model saved at episode 97500
# 💾 Model saved at episode 98000
# 💾 Model saved at episode 98500
# 💾 Model saved at episode 99000
# 💾 Model saved at episode 99500
# Episode 100000 | Reward:   1.28 | Avg:  -3.45 📉 | Success: 40.00% | Budget Exceeded: 60.00% 📈 | Entropy: 0.444 📈 | LR: 2.87e-07
# 💾 Model saved at episode 100000
#
# ==========================================================================================
# BUDGET-AWARE TRAINING COMPLETED
# ==========================================================================================
# Training time: 2180.96 seconds
# Best average reward (last 100): -1.126
# Final average reward (last 100): -3.449
# Final success rate (last 100): 40.00%
# Final budget exceeded rate (last 100): 60.00% 🎯
# Final entropy: 0.444 (max possible: 1.386)
# Final learning rate: 2.87e-07
# First positive reward: Episode 60
# Learning rate decayed 66 times during training
#
# Evaluating budget-aware policy over 50 episodes...
# Budget-Aware Evaluation Results:
#   Mean Reward: -1.507 ± 3.380
#   Mean Length: 11.10
#   Mean Cost: 121.52
#   Mean Skill Improvement: 2.573
#   Mean Budget Utilization: 68.00%
#   Success Rate: 68.00% 🎯
#   Budget Exceeded Rate: 32.00% 💰
#   Reward Improvement from Start: +5.046
#   Training Time: 2180.96s
#   Final Success Rate: 68.00%
#   Final Budget Exceeded Rate: 32.00%
#   Final Mean Reward: -1.507
#
# Testing Configuration: terminal_focus_strong
#   Reward Strategy: terminal
#   Cost Penalty: 0.008
#   Budget Penalties: base=5.0, max=10.0
#   Entropy Coefficient: 0.001
# --------------------------------------------------
# Initialized budget-aware agent with LR=0.0003, cost_penalty=0.008, step_size=750
# Starting Budget-Aware Training with Enhanced Cost Penalties...
# Episodes: 100000
# Environment: 8 skills, 4 training modules
# Agent: Actor-Critic with entropy regularization
# Reward Strategy: terminal
# Learning Rate: 0.0003 (StepLR: step=750, gamma=0.9)
# Cost Penalty: 0.008 (5x increased for budget awareness)
# Budget Penalties: base=5.0, max=10.0
# ------------------------------------------------------------------------------------------
# 🎉 First positive reward achieved at episode 23!
# 💾 Model saved at episode 500
# 💾 Model saved at episode 1000
# 💾 Model saved at episode 1500
# 💾 Model saved at episode 2000
# 💾 Model saved at episode 2500
# 💾 Model saved at episode 3000
# 💾 Model saved at episode 3500
# 💾 Model saved at episode 4000
# 💾 Model saved at episode 4500
# Episode 5000 | Reward:  -3.94 | Avg:   4.21 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.709 📈 | LR: 1.59e-04
# 💾 Model saved at episode 5000
# 💾 Model saved at episode 5500
# 💾 Model saved at episode 6000
# 💾 Model saved at episode 6500
# 💾 Model saved at episode 7000
# 💾 Model saved at episode 7500
# 💾 Model saved at episode 8000
# 💾 Model saved at episode 8500
# 💾 Model saved at episode 9000
# 💾 Model saved at episode 9500
# Episode 10000 | Reward:  -3.34 | Avg:   2.86 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.697 📈 | LR: 7.63e-05
# 💾 Model saved at episode 10000
# 💾 Model saved at episode 10500
# 💾 Model saved at episode 11000
# 💾 Model saved at episode 11500
# 💾 Model saved at episode 12000
# 💾 Model saved at episode 12500
# 💾 Model saved at episode 13000
# 💾 Model saved at episode 13500
# 💾 Model saved at episode 14000
# 💾 Model saved at episode 14500
# Episode 15000 | Reward:  21.29 | Avg:   2.03 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.679 📈 | LR: 3.65e-05
# 💾 Model saved at episode 15000
# 💾 Model saved at episode 15500
# 💾 Model saved at episode 16000
# 💾 Model saved at episode 16500
# 💾 Model saved at episode 17000
# 💾 Model saved at episode 17500
# 💾 Model saved at episode 18000
# 💾 Model saved at episode 18500
# 💾 Model saved at episode 19000
# 💾 Model saved at episode 19500
# Episode 20000 | Reward:  -3.49 | Avg:   5.00 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.673 📉 | LR: 1.94e-05
# 💾 Model saved at episode 20000
# 💾 Model saved at episode 20500
# 💾 Model saved at episode 21000
# 💾 Model saved at episode 21500
# 💾 Model saved at episode 22000
# 💾 Model saved at episode 22500
# 💾 Model saved at episode 23000
# 💾 Model saved at episode 23500
# 💾 Model saved at episode 24000
# 💾 Model saved at episode 24500
# Episode 25000 | Reward:  21.38 | Avg:   4.77 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.668 📉 | LR: 9.27e-06
# 💾 Model saved at episode 25000
# 💾 Model saved at episode 25500
# 💾 Model saved at episode 26000
# 💾 Model saved at episode 26500
# 💾 Model saved at episode 27000
# 💾 Model saved at episode 27500
# 💾 Model saved at episode 28000
# 💾 Model saved at episode 28500
# 💾 Model saved at episode 29000
# 💾 Model saved at episode 29500
# Episode 30000 | Reward:  21.04 | Avg:   4.28 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.650 📉 | LR: 4.43e-06
# 💾 Model saved at episode 30000
# 💾 Model saved at episode 30500
# 💾 Model saved at episode 31000
# 💾 Model saved at episode 31500
# 💾 Model saved at episode 32000
# 💾 Model saved at episode 32500
# 💾 Model saved at episode 33000
# 💾 Model saved at episode 33500
# 💾 Model saved at episode 34000
# 💾 Model saved at episode 34500
# Episode 35000 | Reward:  19.97 | Avg:   4.49 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.647 📈 | LR: 2.36e-06
# 💾 Model saved at episode 35000
# 💾 Model saved at episode 35500
# 💾 Model saved at episode 36000
# 💾 Model saved at episode 36500
# 💾 Model saved at episode 37000
# 💾 Model saved at episode 37500
# 💾 Model saved at episode 38000
# 💾 Model saved at episode 38500
# 💾 Model saved at episode 39000
# 💾 Model saved at episode 39500
# Episode 40000 | Reward:  -3.86 | Avg:   5.01 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.645 📉 | LR: 1.13e-06
# 💾 Model saved at episode 40000
# 💾 Model saved at episode 40500
# 💾 Model saved at episode 41000
# 💾 Model saved at episode 41500
# 💾 Model saved at episode 42000
# 💾 Model saved at episode 42500
# 💾 Model saved at episode 43000
# 💾 Model saved at episode 43500
# 💾 Model saved at episode 44000
# 💾 Model saved at episode 44500
# Episode 45000 | Reward:  21.60 | Avg:   6.53 📈 | Success: 41.00% | Budget Exceeded: 59.00% 📉 | Entropy: 0.653 📉 | LR: 5.39e-07
# 💾 Model saved at episode 45000
# 💾 Model saved at episode 45500
# 💾 Model saved at episode 46000
# 💾 Model saved at episode 46500
# 💾 Model saved at episode 47000
# 💾 Model saved at episode 47500
# 💾 Model saved at episode 48000
# 💾 Model saved at episode 48500
# 💾 Model saved at episode 49000
# 💾 Model saved at episode 49500
# Episode 50000 | Reward:  -4.23 | Avg:   5.07 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.635 📈 | LR: 2.87e-07
# 💾 Model saved at episode 50000
# 💾 Model saved at episode 50500
# 💾 Model saved at episode 51000
# 💾 Model saved at episode 51500
# 💾 Model saved at episode 52000
# 💾 Model saved at episode 52500
# 💾 Model saved at episode 53000
# 💾 Model saved at episode 53500
# 💾 Model saved at episode 54000
# 💾 Model saved at episode 54500
# Episode 55000 | Reward:  20.34 | Avg:   5.53 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.653 📈 | LR: 1.37e-07
# 💾 Model saved at episode 55000
# 💾 Model saved at episode 55500
# 💾 Model saved at episode 56000
# 💾 Model saved at episode 56500
# 💾 Model saved at episode 57000
# 💾 Model saved at episode 57500
# 💾 Model saved at episode 58000
# 💾 Model saved at episode 58500
# 💾 Model saved at episode 59000
# 💾 Model saved at episode 59500
# Episode 60000 | Reward:  20.11 | Avg:   7.20 📉 | Success: 44.00% | Budget Exceeded: 56.00% 📈 | Entropy: 0.648 📉 | LR: 6.55e-08
# 💾 Model saved at episode 60000
# 💾 Model saved at episode 60500
# 💾 Model saved at episode 61000
# 💾 Model saved at episode 61500
# 💾 Model saved at episode 62000
# 💾 Model saved at episode 62500
# 💾 Model saved at episode 63000
# 💾 Model saved at episode 63500
# 💾 Model saved at episode 64000
# 💾 Model saved at episode 64500
# Episode 65000 | Reward:  -3.29 | Avg:   3.57 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.658 📈 | LR: 3.48e-08
# 💾 Model saved at episode 65000
# 💾 Model saved at episode 65500
# 💾 Model saved at episode 66000
# 💾 Model saved at episode 66500
# 💾 Model saved at episode 67000
# 💾 Model saved at episode 67500
# 💾 Model saved at episode 68000
# 💾 Model saved at episode 68500
# 💾 Model saved at episode 69000
# 💾 Model saved at episode 69500
# Episode 70000 | Reward:  -3.49 | Avg:   4.33 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.651 📈 | LR: 1.67e-08
# 💾 Model saved at episode 70000
# 💾 Model saved at episode 70500
# 💾 Model saved at episode 71000
# 💾 Model saved at episode 71500
# 💾 Model saved at episode 72000
# 💾 Model saved at episode 72500
# 💾 Model saved at episode 73000
# 💾 Model saved at episode 73500
# 💾 Model saved at episode 74000
# 💾 Model saved at episode 74500
# Episode 75000 | Reward:  -3.59 | Avg:   4.01 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.644 📉 | LR: 7.97e-09
# 💾 Model saved at episode 75000
# 💾 Model saved at episode 75500
# 💾 Model saved at episode 76000
# 💾 Model saved at episode 76500
# 💾 Model saved at episode 77000
# 💾 Model saved at episode 77500
# 💾 Model saved at episode 78000
# 💾 Model saved at episode 78500
# 💾 Model saved at episode 79000
# 💾 Model saved at episode 79500
# Episode 80000 | Reward:  -3.81 | Avg:   1.11 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.645 📈 | LR: 4.23e-09
# 💾 Model saved at episode 80000
# 💾 Model saved at episode 80500
# 💾 Model saved at episode 81000
# 💾 Model saved at episode 81500
# 💾 Model saved at episode 82000
# 💾 Model saved at episode 82500
# 💾 Model saved at episode 83000
# 💾 Model saved at episode 83500
# 💾 Model saved at episode 84000
# 💾 Model saved at episode 84500
# Episode 85000 | Reward:  -3.73 | Avg:   6.01 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.639 📉 | LR: 2.03e-09
# 💾 Model saved at episode 85000
# 💾 Model saved at episode 85500
# 💾 Model saved at episode 86000
# 💾 Model saved at episode 86500
# 💾 Model saved at episode 87000
# 💾 Model saved at episode 87500
# 💾 Model saved at episode 88000
# 💾 Model saved at episode 88500
# 💾 Model saved at episode 89000
# 💾 Model saved at episode 89500
# Episode 90000 | Reward:  21.09 | Avg:   6.27 📉 | Success: 40.00% | Budget Exceeded: 60.00% 📈 | Entropy: 0.642 📈 | LR: 9.69e-10
# 💾 Model saved at episode 90000
# 💾 Model saved at episode 90500
# 💾 Model saved at episode 91000
# 💾 Model saved at episode 91500
# 💾 Model saved at episode 92000
# 💾 Model saved at episode 92500
# 💾 Model saved at episode 93000
# 💾 Model saved at episode 93500
# 💾 Model saved at episode 94000
# 💾 Model saved at episode 94500
# Episode 95000 | Reward:  20.12 | Avg:   3.59 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.651 📈 | LR: 5.15e-10
# 💾 Model saved at episode 95000
# 💾 Model saved at episode 95500
# 💾 Model saved at episode 96000
# 💾 Model saved at episode 96500
# 💾 Model saved at episode 97000
# 💾 Model saved at episode 97500
# 💾 Model saved at episode 98000
# 💾 Model saved at episode 98500
# 💾 Model saved at episode 99000
# 💾 Model saved at episode 99500
# Episode 100000 | Reward:  20.85 | Avg:   2.39 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.649 📉 | LR: 2.46e-10
# 💾 Model saved at episode 100000
#
# ==========================================================================================
# BUDGET-AWARE TRAINING COMPLETED
# ==========================================================================================
# Training time: 2188.17 seconds
# Best average reward (last 100): 8.789
# Final average reward (last 100): 2.387
# Final success rate (last 100): 24.00%
# Final budget exceeded rate (last 100): 76.00% 🎯
# Final entropy: 0.649 (max possible: 1.386)
# Final learning rate: 2.46e-10
# First positive reward: Episode 23
# Learning rate decayed 133 times during training
#
# Evaluating budget-aware policy over 50 episodes...
# Budget-Aware Evaluation Results:
#   Mean Reward: 13.154 ± 11.407
#   Mean Length: 11.18
#   Mean Cost: 121.88
#   Mean Skill Improvement: 2.644
#   Mean Budget Utilization: 68.00%
#   Success Rate: 68.00% 🎯
#   Budget Exceeded Rate: 32.00% 💰
#   Reward Improvement from Start: +15.153
#   Training Time: 2188.17s
#   Final Success Rate: 68.00%
#   Final Budget Exceeded Rate: 32.00%
#   Final Mean Reward: 13.154
#
# Testing Configuration: fast_learner_frugal
#   Reward Strategy: hybrid
#   Cost Penalty: 0.02
#   Budget Penalties: base=5.0, max=10.0
#   Entropy Coefficient: 0.001
# --------------------------------------------------
# Initialized budget-aware agent with LR=0.0005, cost_penalty=0.02, step_size=1500
# Starting Budget-Aware Training with Enhanced Cost Penalties...
# Episodes: 100000
# Environment: 8 skills, 4 training modules
# Agent: Actor-Critic with entropy regularization
# Reward Strategy: hybrid
# Learning Rate: 0.0005 (StepLR: step=1500, gamma=0.9)
# Cost Penalty: 0.02 (5x increased for budget awareness)
# Budget Penalties: base=5.0, max=10.0
# ------------------------------------------------------------------------------------------
# 🎉 First positive reward achieved at episode 10!
# 💾 Model saved at episode 500
# 💾 Model saved at episode 1000
# 💾 Model saved at episode 1500
# 💾 Model saved at episode 2000
# 💾 Model saved at episode 2500
# 💾 Model saved at episode 3000
# 💾 Model saved at episode 3500
# 💾 Model saved at episode 4000
# 💾 Model saved at episode 4500
# Episode 5000 | Reward:   1.28 | Avg:  -1.34 📈 | Success: 55.00% | Budget Exceeded: 45.00% 📉 | Entropy: 0.459 📉 | LR: 3.65e-04
# 💾 Model saved at episode 5000
# 💾 Model saved at episode 5500
# 💾 Model saved at episode 6000
# 💾 Model saved at episode 6500
# 💾 Model saved at episode 7000
# 💾 Model saved at episode 7500
# 💾 Model saved at episode 8000
# 💾 Model saved at episode 8500
# 💾 Model saved at episode 9000
# 💾 Model saved at episode 9500
# Episode 10000 | Reward:  -4.76 | Avg:  -1.10 📉 | Success: 60.00% | Budget Exceeded: 40.00% 📈 | Entropy: 0.317 📉 | LR: 2.66e-04
# 💾 Model saved at episode 10000
# 💾 Model saved at episode 10500
# 💾 Model saved at episode 11000
# 💾 Model saved at episode 11500
# 💾 Model saved at episode 12000
# 💾 Model saved at episode 12500
# 💾 Model saved at episode 13000
# 💾 Model saved at episode 13500
# 💾 Model saved at episode 14000
# 💾 Model saved at episode 14500
# Episode 15000 | Reward:   1.85 | Avg:  -0.41 📉 | Success: 68.00% | Budget Exceeded: 32.00% 📈 | Entropy: 0.266 📈 | LR: 1.74e-04
# 💾 Model saved at episode 15000
# 💾 Model saved at episode 15500
# 💾 Model saved at episode 16000
# 🎯 80% success rate achieved at episode 16040!
# 💰 Budget discipline achieved (≤20% exceeded) at episode 16040!
# 💾 Model saved at episode 16500
# 💾 Model saved at episode 17000
# 💾 Model saved at episode 17500
# 💾 Model saved at episode 18000
# 💾 Model saved at episode 18500
# 💾 Model saved at episode 19000
# 💾 Model saved at episode 19500
# Episode 20000 | Reward:   1.58 | Avg:  -0.14 📈 | Success: 73.00% | Budget Exceeded: 27.00% 📉 | Entropy: 0.246 📈 | LR: 1.27e-04
# 💾 Model saved at episode 20000
# 💾 Model saved at episode 20500
# 💾 Model saved at episode 21000
# 💾 Model saved at episode 21500
# 💾 Model saved at episode 22000
# 💾 Model saved at episode 22500
# 💾 Model saved at episode 23000
# 💾 Model saved at episode 23500
# 💾 Model saved at episode 24000
# 💾 Model saved at episode 24500
# Episode 25000 | Reward:   1.77 | Avg:  -0.24 📉 | Success: 72.00% | Budget Exceeded: 28.00% 📈 | Entropy: 0.235 📈 | LR: 9.27e-05
# 💾 Model saved at episode 25000
# 💾 Model saved at episode 25500
# 💾 Model saved at episode 26000
# 💾 Model saved at episode 26500
# 💾 Model saved at episode 27000
# 💾 Model saved at episode 27500
# 💾 Model saved at episode 28000
# 💾 Model saved at episode 28500
# 💾 Model saved at episode 29000
# 💾 Model saved at episode 29500
# Episode 30000 | Reward:   1.21 | Avg:  -0.79 📈 | Success: 64.00% | Budget Exceeded: 36.00% 📉 | Entropy: 0.231 📉 | LR: 6.08e-05
# 💾 Model saved at episode 30000
# 💾 Model saved at episode 30500
# 💾 Model saved at episode 31000
# 💾 Model saved at episode 31500
# 💾 Model saved at episode 32000
# 💾 Model saved at episode 32500
# 💾 Model saved at episode 33000
# 💾 Model saved at episode 33500
# 💾 Model saved at episode 34000
# 💾 Model saved at episode 34500
# Episode 35000 | Reward:   0.92 | Avg:  -0.09 📉 | Success: 74.00% | Budget Exceeded: 26.00% 📈 | Entropy: 0.219 📈 | LR: 4.43e-05
# 💾 Model saved at episode 35000
# 💾 Model saved at episode 35500
# 💾 Model saved at episode 36000
# 💾 Model saved at episode 36500
# 💾 Model saved at episode 37000
# 💾 Model saved at episode 37500
# 💾 Model saved at episode 38000
# 💾 Model saved at episode 38500
# 💾 Model saved at episode 39000
# 💾 Model saved at episode 39500
# Episode 40000 | Reward:   1.80 | Avg:   0.53 📉 | Success: 84.00% | Budget Exceeded: 16.00% 📈 | Entropy: 0.223 📉 | LR: 3.23e-05
# 💾 Model saved at episode 40000
# 💾 Model saved at episode 40500
# 💾 Model saved at episode 41000
# 💾 Model saved at episode 41500
# 💾 Model saved at episode 42000
# 💾 Model saved at episode 42500
# 💾 Model saved at episode 43000
# 💾 Model saved at episode 43500
# 💾 Model saved at episode 44000
# 💾 Model saved at episode 44500
# Episode 45000 | Reward:   0.98 | Avg:  -0.56 📉 | Success: 68.00% | Budget Exceeded: 32.00% 📈 | Entropy: 0.214 📈 | LR: 2.12e-05
# 💾 Model saved at episode 45000
# 💾 Model saved at episode 45500
# 💾 Model saved at episode 46000
# 💾 Model saved at episode 46500
# 💾 Model saved at episode 47000
# 💾 Model saved at episode 47500
# 💾 Model saved at episode 48000
# 💾 Model saved at episode 48500
# 💾 Model saved at episode 49000
# 💾 Model saved at episode 49500
# Episode 50000 | Reward:   0.93 | Avg:   0.10 📉 | Success: 78.00% | Budget Exceeded: 22.00% 📈 | Entropy: 0.214 📈 | LR: 1.55e-05
# 💾 Model saved at episode 50000
# 💾 Model saved at episode 50500
# 💾 Model saved at episode 51000
# 💾 Model saved at episode 51500
# 💾 Model saved at episode 52000
# 💾 Model saved at episode 52500
# 💾 Model saved at episode 53000
# 💾 Model saved at episode 53500
# 💾 Model saved at episode 54000
# 💾 Model saved at episode 54500
# Episode 55000 | Reward:  -4.33 | Avg:   0.10 📉 | Success: 76.00% | Budget Exceeded: 24.00% 📈 | Entropy: 0.213 📈 | LR: 1.13e-05
# 💾 Model saved at episode 55000
# 💾 Model saved at episode 55500
# 💾 Model saved at episode 56000
# 💾 Model saved at episode 56500
# 💾 Model saved at episode 57000
# 💾 Model saved at episode 57500
# 💾 Model saved at episode 58000
# 💾 Model saved at episode 58500
# 💾 Model saved at episode 59000
# 💾 Model saved at episode 59500
# Episode 60000 | Reward:  -5.83 | Avg:   0.26 📈 | Success: 79.00% | Budget Exceeded: 21.00% 📉 | Entropy: 0.214 📈 | LR: 7.39e-06
# 💾 Model saved at episode 60000
# 💾 Model saved at episode 60500
# 💾 Model saved at episode 61000
# 💾 Model saved at episode 61500
# 💾 Model saved at episode 62000
# 💾 Model saved at episode 62500
# 💾 Model saved at episode 63000
# 💾 Model saved at episode 63500
# 💾 Model saved at episode 64000
# 💾 Model saved at episode 64500
# Episode 65000 | Reward:   1.30 | Avg:   0.52 📉 | Success: 84.00% | Budget Exceeded: 16.00% 📈 | Entropy: 0.209 📈 | LR: 5.39e-06
# 💾 Model saved at episode 65000
# 💾 Model saved at episode 65500
# 💾 Model saved at episode 66000
# 💾 Model saved at episode 66500
# 💾 Model saved at episode 67000
# 💾 Model saved at episode 67500
# 💾 Model saved at episode 68000
# 💾 Model saved at episode 68500
# 💾 Model saved at episode 69000
# 💾 Model saved at episode 69500
# Episode 70000 | Reward:   0.96 | Avg:   0.36 📈 | Success: 81.00% | Budget Exceeded: 19.00% 📉 | Entropy: 0.208 📉 | LR: 3.93e-06
# 💾 Model saved at episode 70000
# 💾 Model saved at episode 70500
# 💾 Model saved at episode 71000
# 💾 Model saved at episode 71500
# 💾 Model saved at episode 72000
# 💾 Model saved at episode 72500
# 💾 Model saved at episode 73000
# 💾 Model saved at episode 73500
# 💾 Model saved at episode 74000
# 💾 Model saved at episode 74500
# Episode 75000 | Reward:   1.50 | Avg:  -0.28 📈 | Success: 72.00% | Budget Exceeded: 28.00% 📉 | Entropy: 0.213 📉 | LR: 2.58e-06
# 💾 Model saved at episode 75000
# 💾 Model saved at episode 75500
# 💾 Model saved at episode 76000
# 💾 Model saved at episode 76500
# 💾 Model saved at episode 77000
# 💾 Model saved at episode 77500
# 💾 Model saved at episode 78000
# 💾 Model saved at episode 78500
# 💾 Model saved at episode 79000
# 💾 Model saved at episode 79500
# Episode 80000 | Reward:   1.54 | Avg:  -0.03 📉 | Success: 76.00% | Budget Exceeded: 24.00% 📈 | Entropy: 0.208 📉 | LR: 1.88e-06
# 💾 Model saved at episode 80000
# 💾 Model saved at episode 80500
# 💾 Model saved at episode 81000
# 💾 Model saved at episode 81500
# 💾 Model saved at episode 82000
# 💾 Model saved at episode 82500
# 💾 Model saved at episode 83000
# 💾 Model saved at episode 83500
# 💾 Model saved at episode 84000
# 💾 Model saved at episode 84500
# Episode 85000 | Reward:   1.65 | Avg:   0.22 📉 | Success: 79.00% | Budget Exceeded: 21.00% 📈 | Entropy: 0.211 📈 | LR: 1.37e-06
# 💾 Model saved at episode 85000
# 💾 Model saved at episode 85500
# 💾 Model saved at episode 86000
# 💾 Model saved at episode 86500
# 💾 Model saved at episode 87000
# 💾 Model saved at episode 87500
# 💾 Model saved at episode 88000
# 💾 Model saved at episode 88500
# 💾 Model saved at episode 89000
# 💾 Model saved at episode 89500
# Episode 90000 | Reward:   1.77 | Avg:  -0.08 📉 | Success: 73.00% | Budget Exceeded: 27.00% 📈 | Entropy: 0.208 📉 | LR: 8.99e-07
# 💾 Model saved at episode 90000
# 💾 Model saved at episode 90500
# 💾 Model saved at episode 91000
# 💾 Model saved at episode 91500
# 💾 Model saved at episode 92000
# 💾 Model saved at episode 92500
# 💾 Model saved at episode 93000
# 💾 Model saved at episode 93500
# 💾 Model saved at episode 94000
# 💾 Model saved at episode 94500
# Episode 95000 | Reward:   3.07 | Avg:   0.49 📈 | Success: 81.00% | Budget Exceeded: 19.00% 📉 | Entropy: 0.207 📈 | LR: 6.55e-07
# 💾 Model saved at episode 95000
# 💾 Model saved at episode 95500
# 💾 Model saved at episode 96000
# 💾 Model saved at episode 96500
# 💾 Model saved at episode 97000
# 💾 Model saved at episode 97500
# 💾 Model saved at episode 98000
# 💾 Model saved at episode 98500
# 💾 Model saved at episode 99000
# 💾 Model saved at episode 99500
# Episode 100000 | Reward:  -4.52 | Avg:   0.04 📉 | Success: 75.00% | Budget Exceeded: 25.00% 📈 | Entropy: 0.206 📉 | LR: 4.78e-07
# 💾 Model saved at episode 100000
#
# ==========================================================================================
# BUDGET-AWARE TRAINING COMPLETED
# ==========================================================================================
# Training time: 2197.75 seconds
# Best average reward (last 100): 1.041
# Final average reward (last 100): 0.035
# Final success rate (last 100): 75.00%
# Final budget exceeded rate (last 100): 25.00% 🎯
# Final entropy: 0.206 (max possible: 1.386)
# Final learning rate: 4.78e-07
# First positive reward: Episode 10
# 80% success milestone: Episode 16040
# Budget discipline milestone: Episode 16040
# Learning rate decayed 66 times during training
#
# Evaluating budget-aware policy over 50 episodes...
# Budget-Aware Evaluation Results:
#   Mean Reward: 0.633 ± 2.530
#   Mean Length: 11.12
#   Mean Cost: 121.20
#   Mean Skill Improvement: 2.716
#   Mean Budget Utilization: 84.00%
#   Success Rate: 84.00% 🎯
#   Budget Exceeded Rate: 16.00% 💰
#   Reward Improvement from Start: +5.130
#   Training Time: 2197.75s
#   Final Success Rate: 84.00%
#   Final Budget Exceeded Rate: 16.00%
#   Final Mean Reward: 0.633
#
# ====================================================================================================
# BUDGET-AWARE PERFORMANCE COMPARISON SUMMARY
# ====================================================================================================
# Rank Configuration        Success Rate Budget Exceed Mean Reward  Budget Discipline
# ----------------------------------------------------------------------------------------------------
# 1    fast_learner_frugal  84.00%       16.00%       0.633        16040
# 2    strong_incentive     76.00%       24.00%       0.447        29235
# 3    balanced_approach    74.00%       26.00%       1.412        44747
# 4    ultra_conservative   68.00%       32.00%       -1.507       Not achieved
# 5    terminal_focus_strong 68.00%       32.00%       13.154       Not achieved
#
# ====================================================================================================
# WINNER (Best Budget Management): fast_learner_frugal
#   Reward Strategy: hybrid
#   Cost Penalty: 0.02
#   Budget Penalties: base=5.0, max=10.0
#   Success Rate: 84.00%
#   Budget Exceeded Rate: 16.00%
#   Budget Discipline Achieved: Episode 16040
#
# Enhanced system execution completed.

# %%
# !python single_file_rl_training_final.py --mode train \
    --episodes 250000 \
    --reward-strategy terminal \
    --cost-penalty 0.008 \
    --entropy-coef 0.001 \
    --base-budget-penalty 5.0 \
    --max-budget-penalty 10.0 \
    --terminal-bonus-multiplier 3.5
# Out:
# Budget-Aware Employee Training Optimization System
# ================================================================================
# Mode: train
# Seed: 42
# User: Soumedhik
# ================================================================================
# Initialized budget-aware agent with LR=0.0003, cost_penalty=0.008, step_size=750
# Environment: 8 skills, 4 training modules
# Agent: Enhanced Actor-Critic
# Reward Strategy: terminal
# Cost Penalty: 0.008
# Learning Rate: 0.0003 (StepLR: 750/0.9)
#
# Starting budget-aware training...
# Starting Budget-Aware Training with Enhanced Cost Penalties...
# Episodes: 250000
# Environment: 8 skills, 4 training modules
# Agent: Actor-Critic with entropy regularization
# Reward Strategy: terminal
# Learning Rate: 0.0003 (StepLR: step=750, gamma=0.9)
# Cost Penalty: 0.008 (5x increased for budget awareness)
# Budget Penalties: base=5.0, max=10.0
# ------------------------------------------------------------------------------------------
# 🎉 First positive reward achieved at episode 9!
# Episode   25 | Reward:  -4.87 | Avg:  -2.14 📉 | Success: 8.00% | Budget Exceeded: 92.00% 📈 | Entropy: 1.382 📈 | LR: 3.00e-04
# Episode   50 | Reward:  -3.93 | Avg:  -2.95 📉 | Success: 4.00% | Budget Exceeded: 96.00% 📈 | Entropy: 1.382 📉 | LR: 3.00e-04
# Episode   75 | Reward:  16.83 | Avg:  -2.94 📉 | Success: 4.00% | Budget Exceeded: 96.00% 📈 | Entropy: 1.380 📉 | LR: 3.00e-04
# Episode  100 | Reward:  -3.97 | Avg:  -2.47 📉 | Success: 6.00% | Budget Exceeded: 94.00% 📈 | Entropy: 1.378 📉 | LR: 3.00e-04
# Episode  125 | Reward:  -3.75 | Avg:  -2.67 📈 | Success: 5.00% | Budget Exceeded: 95.00% 📉 | Entropy: 1.371 📉 | LR: 3.00e-04
# Episode  150 | Reward:  -3.41 | Avg:  -2.22 📈 | Success: 7.00% | Budget Exceeded: 93.00% 📉 | Entropy: 1.362 📉 | LR: 3.00e-04
# Episode  175 | Reward:  -3.83 | Avg:  -2.18 📉 | Success: 7.00% | Budget Exceeded: 93.00% 📈 | Entropy: 1.351 📉 | LR: 3.00e-04
# Episode  200 | Reward:  -3.43 | Avg:  -2.62 📈 | Success: 5.00% | Budget Exceeded: 95.00% 📉 | Entropy: 1.339 📉 | LR: 3.00e-04
# Episode  225 | Reward:  -3.83 | Avg:  -2.35 📉 | Success: 6.00% | Budget Exceeded: 94.00% 📈 | Entropy: 1.326 📉 | LR: 3.00e-04
# Episode  250 | Reward:  -3.33 | Avg:  -2.52 📈 | Success: 5.00% | Budget Exceeded: 95.00% 📉 | Entropy: 1.313 📉 | LR: 3.00e-04
# Episode  275 | Reward:  -3.44 | Avg:  -2.76 📈 | Success: 4.00% | Budget Exceeded: 96.00% 📈 | Entropy: 1.297 📉 | LR: 3.00e-04
# Episode  300 | Reward:  -3.68 | Avg:  -2.76 📉 | Success: 4.00% | Budget Exceeded: 96.00% 📈 | Entropy: 1.269 📉 | LR: 3.00e-04
# Episode  325 | Reward:  19.70 | Avg:  -2.98 📉 | Success: 3.00% | Budget Exceeded: 97.00% 📈 | Entropy: 1.225 📉 | LR: 3.00e-04
# Episode  350 | Reward:  -3.70 | Avg:  -2.50 📈 | Success: 5.00% | Budget Exceeded: 95.00% 📉 | Entropy: 1.186 📉 | LR: 3.00e-04
# Episode  375 | Reward:  -3.86 | Avg:  -2.25 📈 | Success: 6.00% | Budget Exceeded: 94.00% 📉 | Entropy: 1.154 📉 | LR: 3.00e-04
# Episode  400 | Reward:  -3.88 | Avg:  -1.48 📈 | Success: 9.00% | Budget Exceeded: 91.00% 📉 | Entropy: 1.129 📉 | LR: 3.00e-04
# Episode  425 | Reward:  -3.31 | Avg:  -0.46 📈 | Success: 13.00% | Budget Exceeded: 87.00% 📉 | Entropy: 1.121 📉 | LR: 3.00e-04
# Episode  450 | Reward:  -3.77 | Avg:  -0.45 📈 | Success: 13.00% | Budget Exceeded: 87.00% 📉 | Entropy: 1.105 📉 | LR: 3.00e-04
# Episode  475 | Reward:  20.67 | Avg:   1.31 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 1.094 📉 | LR: 3.00e-04
# Episode  500 | Reward:  -3.46 | Avg:   1.06 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 1.091 📉 | LR: 3.00e-04
# 💾 Model saved at episode 500
# Episode  525 | Reward:  -3.80 | Avg:   0.09 📈 | Success: 15.00% | Budget Exceeded: 85.00% 📉 | Entropy: 1.087 📈 | LR: 3.00e-04
# Episode  550 | Reward:  -3.31 | Avg:   0.35 📉 | Success: 16.00% | Budget Exceeded: 84.00% 📈 | Entropy: 1.078 📉 | LR: 3.00e-04
# Episode  575 | Reward:  22.16 | Avg:  -0.67 📈 | Success: 12.00% | Budget Exceeded: 88.00% 📈 | Entropy: 1.055 📉 | LR: 3.00e-04
# Episode  600 | Reward:  -3.05 | Avg:  -0.89 📈 | Success: 11.00% | Budget Exceeded: 89.00% 📉 | Entropy: 1.036 📉 | LR: 3.00e-04
# Episode  625 | Reward:  21.44 | Avg:   0.08 📉 | Success: 15.00% | Budget Exceeded: 85.00% 📈 | Entropy: 1.013 📉 | LR: 3.00e-04
# Episode  650 | Reward:  -3.88 | Avg:  -0.68 📉 | Success: 12.00% | Budget Exceeded: 88.00% 📈 | Entropy: 0.999 📉 | LR: 3.00e-04
# Episode  675 | Reward:  20.94 | Avg:  -0.90 📈 | Success: 11.00% | Budget Exceeded: 89.00% 📉 | Entropy: 0.982 📉 | LR: 3.00e-04
# Episode  700 | Reward:  -4.38 | Avg:  -1.11 📉 | Success: 10.00% | Budget Exceeded: 90.00% 📈 | Entropy: 0.962 📉 | LR: 3.00e-04
# Episode  725 | Reward:  -4.04 | Avg:  -1.12 📈 | Success: 10.00% | Budget Exceeded: 90.00% 📉 | Entropy: 0.953 📉 | LR: 3.00e-04
# Episode  750 | Reward:  -3.91 | Avg:  -0.65 📉 | Success: 12.00% | Budget Exceeded: 88.00% 📈 | Entropy: 0.942 📉 | LR: 2.70e-04
# Episode  775 | Reward:  -3.52 | Avg:  -0.47 📈 | Success: 13.00% | Budget Exceeded: 87.00% 📉 | Entropy: 0.941 📈 | LR: 2.70e-04
# Episode  800 | Reward:  -3.84 | Avg:  -0.28 📉 | Success: 14.00% | Budget Exceeded: 86.00% 📈 | Entropy: 0.947 📉 | LR: 2.70e-04
# Episode  825 | Reward:  20.35 | Avg:  -0.53 📈 | Success: 13.00% | Budget Exceeded: 87.00% 📉 | Entropy: 0.952 📈 | LR: 2.70e-04
# Episode  850 | Reward:  -3.63 | Avg:  -0.51 📉 | Success: 13.00% | Budget Exceeded: 87.00% 📈 | Entropy: 0.965 📈 | LR: 2.70e-04
# Episode  875 | Reward:  22.12 | Avg:  -0.23 📈 | Success: 14.00% | Budget Exceeded: 86.00% 📉 | Entropy: 0.968 📈 | LR: 2.70e-04
# Episode  900 | Reward:  -3.34 | Avg:   0.32 📉 | Success: 16.00% | Budget Exceeded: 84.00% 📈 | Entropy: 0.960 📉 | LR: 2.70e-04
# Episode  925 | Reward:  -4.06 | Avg:   0.34 📈 | Success: 16.00% | Budget Exceeded: 84.00% 📉 | Entropy: 0.948 📉 | LR: 2.70e-04
# Episode  950 | Reward:  -3.99 | Avg:   0.59 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.926 📉 | LR: 2.70e-04
# Episode  975 | Reward:  -3.67 | Avg:   0.13 📉 | Success: 15.00% | Budget Exceeded: 85.00% 📈 | Entropy: 0.912 📉 | LR: 2.70e-04
# Episode 1000 | Reward:  21.45 | Avg:   0.07 📉 | Success: 15.00% | Budget Exceeded: 85.00% 📈 | Entropy: 0.907 📉 | LR: 2.70e-04
# 💾 Model saved at episode 1000
# Episode 1025 | Reward:  -3.49 | Avg:  -0.19 📉 | Success: 14.00% | Budget Exceeded: 86.00% 📈 | Entropy: 0.906 📈 | LR: 2.70e-04
# Episode 1050 | Reward:  -3.25 | Avg:  -0.88 📉 | Success: 11.00% | Budget Exceeded: 89.00% 📈 | Entropy: 0.911 📈 | LR: 2.70e-04
# Episode 1075 | Reward:  -2.96 | Avg:  -0.89 📉 | Success: 11.00% | Budget Exceeded: 89.00% 📈 | Entropy: 0.918 📈 | LR: 2.70e-04
# Episode 1100 | Reward:  -3.25 | Avg:  -1.12 📉 | Success: 10.00% | Budget Exceeded: 90.00% 📈 | Entropy: 0.923 📈 | LR: 2.70e-04
# Episode 1125 | Reward:  -3.91 | Avg:  -0.90 📈 | Success: 11.00% | Budget Exceeded: 89.00% 📉 | Entropy: 0.919 📉 | LR: 2.70e-04
# Episode 1150 | Reward:  -3.60 | Avg:  -1.16 📉 | Success: 10.00% | Budget Exceeded: 90.00% 📈 | Entropy: 0.911 📉 | LR: 2.70e-04
# Episode 1175 | Reward:  21.33 | Avg:  -1.18 📉 | Success: 10.00% | Budget Exceeded: 90.00% 📈 | Entropy: 0.906 📉 | LR: 2.70e-04
# Episode 1200 | Reward:  -3.14 | Avg:  -1.42 📉 | Success: 9.00% | Budget Exceeded: 91.00% 📈 | Entropy: 0.905 📈 | LR: 2.70e-04
# Episode 1225 | Reward:  -4.08 | Avg:  -1.91 📈 | Success: 7.00% | Budget Exceeded: 93.00% 📉 | Entropy: 0.909 📈 | LR: 2.70e-04
# Episode 1250 | Reward:  21.04 | Avg:  -0.18 📈 | Success: 14.00% | Budget Exceeded: 86.00% 📉 | Entropy: 0.913 📈 | LR: 2.70e-04
# Episode 1275 | Reward:  -3.56 | Avg:   0.05 📈 | Success: 15.00% | Budget Exceeded: 85.00% 📉 | Entropy: 0.910 📉 | LR: 2.70e-04
# Episode 1300 | Reward:  -4.06 | Avg:   0.80 📈 | Success: 18.00% | Budget Exceeded: 82.00% 📉 | Entropy: 0.902 📉 | LR: 2.70e-04
# Episode 1325 | Reward:  -3.48 | Avg:   0.56 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.883 📉 | LR: 2.70e-04
# Episode 1350 | Reward:  -4.02 | Avg:  -0.19 📉 | Success: 14.00% | Budget Exceeded: 86.00% 📈 | Entropy: 0.874 📉 | LR: 2.70e-04
# Episode 1375 | Reward:  -3.69 | Avg:  -0.41 📉 | Success: 13.00% | Budget Exceeded: 87.00% 📈 | Entropy: 0.868 📉 | LR: 2.70e-04
# Episode 1400 | Reward:  21.03 | Avg:  -0.90 📈 | Success: 11.00% | Budget Exceeded: 89.00% 📉 | Entropy: 0.864 📈 | LR: 2.70e-04
# Episode 1425 | Reward:  -3.64 | Avg:   0.07 📉 | Success: 15.00% | Budget Exceeded: 85.00% 📈 | Entropy: 0.872 📈 | LR: 2.70e-04
# Episode 1450 | Reward:  -3.75 | Avg:   0.32 📈 | Success: 16.00% | Budget Exceeded: 84.00% 📉 | Entropy: 0.876 📈 | LR: 2.70e-04
# Episode 1475 | Reward:  -3.72 | Avg:   1.27 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 0.880 📈 | LR: 2.70e-04
# Episode 1500 | Reward:  -4.08 | Avg:   2.01 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.886 📈 | LR: 2.43e-04
# 💾 Model saved at episode 1500
# Episode 1525 | Reward:  -3.67 | Avg:   2.06 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.890 📈 | LR: 2.43e-04
# Episode 1550 | Reward:  21.67 | Avg:   2.32 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.891 📈 | LR: 2.43e-04
# Episode 1575 | Reward:  21.54 | Avg:   2.13 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.886 📉 | LR: 2.43e-04
# Episode 1600 | Reward:  -3.84 | Avg:   1.14 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.881 📉 | LR: 2.43e-04
# Episode 1625 | Reward:  21.19 | Avg:   0.65 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.879 📉 | LR: 2.43e-04
# Episode 1650 | Reward:  20.81 | Avg:  -0.06 📉 | Success: 14.00% | Budget Exceeded: 86.00% 📈 | Entropy: 0.881 📈 | LR: 2.43e-04
# Episode 1675 | Reward:  -3.72 | Avg:  -0.58 📈 | Success: 12.00% | Budget Exceeded: 88.00% 📉 | Entropy: 0.883 📈 | LR: 2.43e-04
# Episode 1700 | Reward:  -3.73 | Avg:  -0.32 📈 | Success: 13.00% | Budget Exceeded: 87.00% 📉 | Entropy: 0.880 📉 | LR: 2.43e-04
# Episode 1725 | Reward:  -3.36 | Avg:  -0.60 📉 | Success: 12.00% | Budget Exceeded: 88.00% 📈 | Entropy: 0.872 📉 | LR: 2.43e-04
# Episode 1750 | Reward:  -3.93 | Avg:  -0.86 📉 | Success: 11.00% | Budget Exceeded: 89.00% 📈 | Entropy: 0.866 📉 | LR: 2.43e-04
# Episode 1775 | Reward:  -3.99 | Avg:  -0.62 📉 | Success: 12.00% | Budget Exceeded: 88.00% 📈 | Entropy: 0.863 📉 | LR: 2.43e-04
# Episode 1800 | Reward:  21.35 | Avg:  -1.10 📈 | Success: 10.00% | Budget Exceeded: 90.00% 📉 | Entropy: 0.862 📈 | LR: 2.43e-04
# Episode 1825 | Reward:  -3.28 | Avg:  -1.09 📈 | Success: 10.00% | Budget Exceeded: 90.00% 📉 | Entropy: 0.863 📉 | LR: 2.43e-04
# Episode 1850 | Reward:  21.40 | Avg:   0.17 📉 | Success: 15.00% | Budget Exceeded: 85.00% 📈 | Entropy: 0.861 📉 | LR: 2.43e-04
# Episode 1875 | Reward:  -3.20 | Avg:   0.19 📈 | Success: 15.00% | Budget Exceeded: 85.00% 📉 | Entropy: 0.861 📉 | LR: 2.43e-04
# Episode 1900 | Reward:  -3.74 | Avg:   0.43 📈 | Success: 16.00% | Budget Exceeded: 84.00% 📉 | Entropy: 0.860 📈 | LR: 2.43e-04
# Episode 1925 | Reward:  21.73 | Avg:   1.17 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.859 📈 | LR: 2.43e-04
# Episode 1950 | Reward:  -3.04 | Avg:   0.64 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.856 📉 | LR: 2.43e-04
# Episode 1975 | Reward:  21.50 | Avg:   0.12 📈 | Success: 15.00% | Budget Exceeded: 85.00% 📉 | Entropy: 0.853 📉 | LR: 2.43e-04
# Episode 2000 | Reward:  -3.78 | Avg:   0.87 📉 | Success: 18.00% | Budget Exceeded: 82.00% 📈 | Entropy: 0.855 📉 | LR: 2.43e-04
# 💾 Model saved at episode 2000
# Episode 2025 | Reward:  -4.04 | Avg:   0.62 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.857 📈 | LR: 2.43e-04
# Episode 2050 | Reward:  -3.16 | Avg:   0.63 📈 | Success: 17.00% | Budget Exceeded: 83.00% 📉 | Entropy: 0.862 📈 | LR: 2.43e-04
# Episode 2075 | Reward:  -3.24 | Avg:   1.12 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.871 📈 | LR: 2.43e-04
# Episode 2100 | Reward:  -3.77 | Avg:   0.86 📈 | Success: 18.00% | Budget Exceeded: 82.00% 📉 | Entropy: 0.871 📈 | LR: 2.43e-04
# Episode 2125 | Reward:  -3.42 | Avg:   1.80 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.874 📈 | LR: 2.43e-04
# Episode 2150 | Reward:  20.92 | Avg:   1.10 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.871 📉 | LR: 2.43e-04
# Episode 2175 | Reward:  -3.78 | Avg:   0.61 📈 | Success: 17.00% | Budget Exceeded: 83.00% 📉 | Entropy: 0.863 📉 | LR: 2.43e-04
# Episode 2200 | Reward:  -3.73 | Avg:   0.61 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.854 📉 | LR: 2.43e-04
# Episode 2225 | Reward:  19.93 | Avg:   0.17 📈 | Success: 15.00% | Budget Exceeded: 85.00% 📉 | Entropy: 0.844 📉 | LR: 2.43e-04
# Episode 2250 | Reward:  21.02 | Avg:   0.88 📈 | Success: 18.00% | Budget Exceeded: 82.00% 📉 | Entropy: 0.834 📉 | LR: 2.19e-04
# Episode 2275 | Reward:  -3.96 | Avg:   1.65 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.828 📉 | LR: 2.19e-04
# Episode 2300 | Reward:  -4.04 | Avg:   1.63 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.831 📈 | LR: 2.19e-04
# Episode 2325 | Reward:  -3.18 | Avg:   1.59 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.830 📈 | LR: 2.19e-04
# Episode 2350 | Reward:  21.17 | Avg:   1.83 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.830 📉 | LR: 2.19e-04
# Episode 2375 | Reward:  -2.86 | Avg:   1.83 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.825 📉 | LR: 2.19e-04
# Episode 2400 | Reward:  -2.83 | Avg:   2.12 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.815 📉 | LR: 2.19e-04
# Episode 2425 | Reward:  -3.06 | Avg:   1.91 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.806 📉 | LR: 2.19e-04
# Episode 2450 | Reward:  20.33 | Avg:   2.13 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.799 📉 | LR: 2.19e-04
# Episode 2475 | Reward:  -2.88 | Avg:   2.11 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.792 📉 | LR: 2.19e-04
# Episode 2500 | Reward:  20.76 | Avg:   2.80 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.787 📉 | LR: 2.19e-04
# 💾 Model saved at episode 2500
# Episode 2525 | Reward:  -3.52 | Avg:   3.51 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.787 📉 | LR: 2.19e-04
# Episode 2550 | Reward:  -3.60 | Avg:   3.05 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.788 📈 | LR: 2.19e-04
# Episode 2575 | Reward:  -3.72 | Avg:   2.32 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.788 📈 | LR: 2.19e-04
# Episode 2600 | Reward:  -3.87 | Avg:   2.09 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.791 📈 | LR: 2.19e-04
# Episode 2625 | Reward:  -3.54 | Avg:   1.41 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📈 | Entropy: 0.794 📈 | LR: 2.19e-04
# Episode 2650 | Reward:  -3.17 | Avg:   0.89 📈 | Success: 18.00% | Budget Exceeded: 82.00% 📉 | Entropy: 0.795 📈 | LR: 2.19e-04
# Episode 2675 | Reward:  -2.83 | Avg:   1.67 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.800 📈 | LR: 2.19e-04
# Episode 2700 | Reward:  -3.88 | Avg:   1.64 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.805 📈 | LR: 2.19e-04
# Episode 2725 | Reward:  -3.64 | Avg:   1.37 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 0.805 📈 | LR: 2.19e-04
# Episode 2750 | Reward:  21.36 | Avg:   1.15 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.804 📉 | LR: 2.19e-04
# Episode 2775 | Reward:  20.57 | Avg:   1.56 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.798 📉 | LR: 2.19e-04
# Episode 2800 | Reward:  -2.91 | Avg:   0.86 📈 | Success: 18.00% | Budget Exceeded: 82.00% 📉 | Entropy: 0.790 📉 | LR: 2.19e-04
# Episode 2825 | Reward:  -3.85 | Avg:   2.06 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.785 📉 | LR: 2.19e-04
# Episode 2850 | Reward:  -4.30 | Avg:   3.49 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.783 📈 | LR: 2.19e-04
# Episode 2875 | Reward:  -3.51 | Avg:   2.05 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.781 📉 | LR: 2.19e-04
# Episode 2900 | Reward:  -3.84 | Avg:   1.76 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.778 📉 | LR: 2.19e-04
# Episode 2925 | Reward:  -3.39 | Avg:   1.24 📉 | Success: 20.00% | Budget Exceeded: 80.00% 📈 | Entropy: 0.775 📉 | LR: 2.19e-04
# Episode 2950 | Reward:  -3.24 | Avg:   0.06 📈 | Success: 15.00% | Budget Exceeded: 85.00% 📉 | Entropy: 0.773 📈 | LR: 2.19e-04
# Episode 2975 | Reward:  -2.96 | Avg:   1.04 📈 | Success: 19.00% | Budget Exceeded: 81.00% 📉 | Entropy: 0.774 📈 | LR: 2.19e-04
# Episode 3000 | Reward:  -2.98 | Avg:   2.02 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.769 📉 | LR: 1.97e-04
# 💾 Model saved at episode 3000
# Episode 3025 | Reward:  20.01 | Avg:   1.78 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.760 📉 | LR: 1.97e-04
# Episode 3050 | Reward:  21.58 | Avg:   2.53 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.754 📉 | LR: 1.97e-04
# Episode 3075 | Reward:  -3.41 | Avg:   1.54 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.746 📉 | LR: 1.97e-04
# Episode 3100 | Reward:  -3.35 | Avg:   1.29 📉 | Success: 20.00% | Budget Exceeded: 80.00% 📈 | Entropy: 0.746 📈 | LR: 1.97e-04
# Episode 3125 | Reward:  -3.59 | Avg:   0.83 📉 | Success: 18.00% | Budget Exceeded: 82.00% 📈 | Entropy: 0.741 📉 | LR: 1.97e-04
# Episode 3150 | Reward:  -3.82 | Avg:   2.00 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.740 📉 | LR: 1.97e-04
# Episode 3175 | Reward:  -3.10 | Avg:   2.99 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.747 📉 | LR: 1.97e-04
# Episode 3200 | Reward:  -3.57 | Avg:   3.49 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.750 📈 | LR: 1.97e-04
# Episode 3225 | Reward:  -3.96 | Avg:   3.97 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.760 📈 | LR: 1.97e-04
# Episode 3250 | Reward:  20.38 | Avg:   2.77 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.765 📉 | LR: 1.97e-04
# Episode 3275 | Reward:  -4.32 | Avg:   2.75 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.758 📉 | LR: 1.97e-04
# Episode 3300 | Reward:  22.07 | Avg:   2.02 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.753 📉 | LR: 1.97e-04
# Episode 3325 | Reward:  20.20 | Avg:   3.26 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.747 📉 | LR: 1.97e-04
# Episode 3350 | Reward:  -3.67 | Avg:   3.02 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.740 📉 | LR: 1.97e-04
# Episode 3375 | Reward:  -3.56 | Avg:   2.77 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.736 📉 | LR: 1.97e-04
# Episode 3400 | Reward:  -4.04 | Avg:   3.24 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.730 📉 | LR: 1.97e-04
# Episode 3425 | Reward:  19.86 | Avg:   1.74 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.731 📉 | LR: 1.97e-04
# Episode 3450 | Reward:  -3.65 | Avg:   2.49 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.733 📈 | LR: 1.97e-04
# Episode 3475 | Reward:  20.63 | Avg:   3.01 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.730 📈 | LR: 1.97e-04
# Episode 3500 | Reward:  -3.44 | Avg:   2.05 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.731 📉 | LR: 1.97e-04
# 💾 Model saved at episode 3500
# Episode 3525 | Reward:  -3.79 | Avg:   2.29 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.729 📉 | LR: 1.97e-04
# Episode 3550 | Reward:  -3.42 | Avg:   1.56 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.730 📈 | LR: 1.97e-04
# Episode 3575 | Reward:  20.96 | Avg:   1.33 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 0.739 📈 | LR: 1.97e-04
# Episode 3600 | Reward:  20.99 | Avg:   2.33 📈 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.742 📈 | LR: 1.97e-04
# Episode 3625 | Reward:  -3.94 | Avg:   2.58 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.745 📈 | LR: 1.97e-04
# Episode 3650 | Reward:  -3.44 | Avg:   2.81 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.749 📉 | LR: 1.97e-04
# Episode 3675 | Reward:  -3.46 | Avg:   3.75 📈 | Success: 30.00% | Budget Exceeded: 70.00% 📉 | Entropy: 0.752 📈 | LR: 1.97e-04
# Episode 3700 | Reward:  20.61 | Avg:   4.24 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.758 📈 | LR: 1.97e-04
# Episode 3725 | Reward:  -3.74 | Avg:   3.97 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.757 📈 | LR: 1.97e-04
# Episode 3750 | Reward:  -3.45 | Avg:   3.49 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.753 📉 | LR: 1.77e-04
# Episode 3775 | Reward:  -3.65 | Avg:   3.23 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.750 📉 | LR: 1.77e-04
# Episode 3800 | Reward:  19.88 | Avg:   2.02 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.750 📈 | LR: 1.77e-04
# Episode 3825 | Reward:  -3.92 | Avg:   2.04 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.753 📈 | LR: 1.77e-04
# Episode 3850 | Reward:  -3.38 | Avg:   2.50 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.755 📉 | LR: 1.77e-04
# Episode 3875 | Reward:  -4.01 | Avg:   1.09 📈 | Success: 19.00% | Budget Exceeded: 81.00% 📉 | Entropy: 0.750 📉 | LR: 1.77e-04
# Episode 3900 | Reward:  -3.46 | Avg:   0.60 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.749 📉 | LR: 1.77e-04
# Episode 3925 | Reward:  -3.98 | Avg:   1.57 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.746 📉 | LR: 1.77e-04
# Episode 3950 | Reward:  -2.92 | Avg:   1.79 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.748 📈 | LR: 1.77e-04
# Episode 3975 | Reward:  20.52 | Avg:   2.26 📈 | Success: 24.00% | Budget Exceeded: 76.00% 📉 | Entropy: 0.751 📉 | LR: 1.77e-04
# Episode 4000 | Reward:  21.01 | Avg:   2.71 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.746 📈 | LR: 1.77e-04
# 💾 Model saved at episode 4000
# Episode 4025 | Reward:  -3.54 | Avg:   0.52 📉 | Success: 17.00% | Budget Exceeded: 83.00% 📈 | Entropy: 0.749 📉 | LR: 1.77e-04
# Episode 4050 | Reward:  20.17 | Avg:   1.00 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.750 📈 | LR: 1.77e-04
# Episode 4075 | Reward:  -3.74 | Avg:   1.26 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 0.752 📈 | LR: 1.77e-04
# Episode 4100 | Reward:  -3.06 | Avg:   1.50 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.757 📈 | LR: 1.77e-04
# Episode 4125 | Reward:  -3.89 | Avg:   2.22 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.753 📉 | LR: 1.77e-04
# Episode 4150 | Reward:  -4.16 | Avg:   2.01 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.749 📉 | LR: 1.77e-04
# Episode 4175 | Reward:  -3.44 | Avg:   0.80 📉 | Success: 18.00% | Budget Exceeded: 82.00% 📈 | Entropy: 0.748 📉 | LR: 1.77e-04
# Episode 4200 | Reward:  -3.71 | Avg:   1.03 📈 | Success: 19.00% | Budget Exceeded: 81.00% 📉 | Entropy: 0.746 📈 | LR: 1.77e-04
# Episode 4225 | Reward:  -3.53 | Avg:   1.55 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.748 📈 | LR: 1.77e-04
# Episode 4250 | Reward:  -3.29 | Avg:   2.06 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.747 📉 | LR: 1.77e-04
# Episode 4275 | Reward:  20.41 | Avg:   2.99 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.744 📉 | LR: 1.77e-04
# Episode 4300 | Reward:  -3.93 | Avg:   3.75 📈 | Success: 30.00% | Budget Exceeded: 70.00% 📉 | Entropy: 0.743 📉 | LR: 1.77e-04
# Episode 4325 | Reward:  -3.52 | Avg:   3.78 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.749 📈 | LR: 1.77e-04
# Episode 4350 | Reward:  -3.39 | Avg:   2.78 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.761 📈 | LR: 1.77e-04
# Episode 4375 | Reward:  -3.96 | Avg:   3.06 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.769 📈 | LR: 1.77e-04
# Episode 4400 | Reward:  -4.02 | Avg:   2.06 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.776 📈 | LR: 1.77e-04
# Episode 4425 | Reward:  20.53 | Avg:   2.53 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.771 📉 | LR: 1.77e-04
# Episode 4450 | Reward:  20.84 | Avg:   2.76 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.764 📉 | LR: 1.77e-04
# Episode 4475 | Reward:  -3.72 | Avg:   3.51 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.762 📉 | LR: 1.77e-04
# Episode 4500 | Reward:  -3.28 | Avg:   4.54 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.756 📈 | LR: 1.59e-04
# 💾 Model saved at episode 4500
# Episode 4525 | Reward:  20.70 | Avg:   4.30 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.755 📉 | LR: 1.59e-04
# Episode 4550 | Reward:  20.09 | Avg:   4.34 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.755 📉 | LR: 1.59e-04
# Episode 4575 | Reward:  -4.12 | Avg:   4.56 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.757 📈 | LR: 1.59e-04
# Episode 4600 | Reward:  20.69 | Avg:   4.06 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.761 📈 | LR: 1.59e-04
# Episode 4625 | Reward:  -4.56 | Avg:   3.56 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.766 📈 | LR: 1.59e-04
# Episode 4650 | Reward:  -3.23 | Avg:   3.56 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.770 📈 | LR: 1.59e-04
# Episode 4675 | Reward:  -3.61 | Avg:   2.60 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.774 📈 | LR: 1.59e-04
# Episode 4700 | Reward:  -3.50 | Avg:   3.08 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.774 📈 | LR: 1.59e-04
# Episode 4725 | Reward:  -3.48 | Avg:   2.60 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.776 📉 | LR: 1.59e-04
# Episode 4750 | Reward:  -3.41 | Avg:   1.85 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.782 📉 | LR: 1.59e-04
# Episode 4775 | Reward:  -3.27 | Avg:   1.61 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.787 📈 | LR: 1.59e-04
# Episode 4800 | Reward:  21.02 | Avg:   1.13 📈 | Success: 19.00% | Budget Exceeded: 81.00% 📉 | Entropy: 0.793 📈 | LR: 1.59e-04
# Episode 4825 | Reward:  -3.30 | Avg:   2.16 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.796 📉 | LR: 1.59e-04
# Episode 4850 | Reward:  -3.59 | Avg:   2.65 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.793 📉 | LR: 1.59e-04
# Episode 4875 | Reward:  -3.37 | Avg:   2.42 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.784 📉 | LR: 1.59e-04
# Episode 4900 | Reward:  -3.09 | Avg:   1.20 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.776 📉 | LR: 1.59e-04
# Episode 4925 | Reward:  -3.58 | Avg:   0.40 📉 | Success: 16.00% | Budget Exceeded: 84.00% 📈 | Entropy: 0.779 📉 | LR: 1.59e-04
# Episode 4950 | Reward:  -4.11 | Avg:   0.15 📉 | Success: 15.00% | Budget Exceeded: 85.00% 📈 | Entropy: 0.778 📈 | LR: 1.59e-04
# Episode 4975 | Reward:  21.05 | Avg:   0.39 📈 | Success: 16.00% | Budget Exceeded: 84.00% 📉 | Entropy: 0.785 📈 | LR: 1.59e-04
# Episode 5000 | Reward:  -3.36 | Avg:   1.12 📈 | Success: 19.00% | Budget Exceeded: 81.00% 📉 | Entropy: 0.790 📉 | LR: 1.59e-04
# 💾 Model saved at episode 5000
# Episode 5025 | Reward:  -3.66 | Avg:   1.85 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.789 📈 | LR: 1.59e-04
# Episode 5050 | Reward:  21.11 | Avg:   1.38 📉 | Success: 20.00% | Budget Exceeded: 80.00% 📈 | Entropy: 0.788 📉 | LR: 1.59e-04
# Episode 5075 | Reward:  -3.42 | Avg:   2.34 📈 | Success: 24.00% | Budget Exceeded: 76.00% 📉 | Entropy: 0.788 📈 | LR: 1.59e-04
# Episode 5100 | Reward:  -3.08 | Avg:   2.09 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.792 📉 | LR: 1.59e-04
# Episode 5125 | Reward:  -3.19 | Avg:   1.62 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.793 📈 | LR: 1.59e-04
# Episode 5150 | Reward:  -3.17 | Avg:   2.60 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.794 📉 | LR: 1.59e-04
# Episode 5175 | Reward:  -3.67 | Avg:   1.37 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 0.790 📉 | LR: 1.59e-04
# Episode 5200 | Reward:  -3.20 | Avg:   2.08 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.784 📉 | LR: 1.59e-04
# Episode 5225 | Reward:  -3.51 | Avg:   1.83 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.774 📉 | LR: 1.59e-04
# Episode 5250 | Reward:  -3.17 | Avg:   1.09 📈 | Success: 19.00% | Budget Exceeded: 81.00% 📉 | Entropy: 0.764 📉 | LR: 1.43e-04
# Episode 5275 | Reward:  -3.86 | Avg:   1.86 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.757 📉 | LR: 1.43e-04
# Episode 5300 | Reward:  21.63 | Avg:   2.13 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.752 📉 | LR: 1.43e-04
# Episode 5325 | Reward:  -4.17 | Avg:   2.63 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.752 📈 | LR: 1.43e-04
# Episode 5350 | Reward:  -3.40 | Avg:   3.61 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.756 📈 | LR: 1.43e-04
# Episode 5375 | Reward:  -3.84 | Avg:   2.83 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.762 📈 | LR: 1.43e-04
# Episode 5400 | Reward:  -3.63 | Avg:   2.07 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.767 📈 | LR: 1.43e-04
# Episode 5425 | Reward:  -3.89 | Avg:   2.05 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.768 📈 | LR: 1.43e-04
# Episode 5450 | Reward:  -3.62 | Avg:   2.30 📈 | Success: 24.00% | Budget Exceeded: 76.00% 📉 | Entropy: 0.768 📉 | LR: 1.43e-04
# Episode 5475 | Reward:  -3.93 | Avg:   3.08 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.761 📉 | LR: 1.43e-04
# Episode 5500 | Reward:  -4.05 | Avg:   3.80 📈 | Success: 30.00% | Budget Exceeded: 70.00% 📉 | Entropy: 0.758 📉 | LR: 1.43e-04
# 💾 Model saved at episode 5500
# Episode 5525 | Reward:  -3.36 | Avg:   3.29 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.760 📉 | LR: 1.43e-04
# Episode 5550 | Reward:  -3.66 | Avg:   2.34 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.760 📈 | LR: 1.43e-04
# Episode 5575 | Reward:  -3.37 | Avg:   2.31 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.764 📈 | LR: 1.43e-04
# Episode 5600 | Reward:  -2.93 | Avg:   2.33 📈 | Success: 24.00% | Budget Exceeded: 76.00% 📉 | Entropy: 0.765 📉 | LR: 1.43e-04
# Episode 5625 | Reward:  -3.86 | Avg:   3.52 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.760 📈 | LR: 1.43e-04
# Episode 5650 | Reward:  -2.96 | Avg:   3.48 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.761 📉 | LR: 1.43e-04
# Episode 5675 | Reward:  20.43 | Avg:   3.23 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.757 📉 | LR: 1.43e-04
# Episode 5700 | Reward:  -3.94 | Avg:   2.76 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.754 📈 | LR: 1.43e-04
# Episode 5725 | Reward:  -3.93 | Avg:   1.82 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.754 📉 | LR: 1.43e-04
# Episode 5750 | Reward:  21.42 | Avg:   1.58 📉 | Success: 21.00% | Budget Exceeded: 79.00% 📈 | Entropy: 0.753 📈 | LR: 1.43e-04
# Episode 5775 | Reward:  -3.97 | Avg:   1.33 📉 | Success: 20.00% | Budget Exceeded: 80.00% 📈 | Entropy: 0.754 📈 | LR: 1.43e-04
# Episode 5800 | Reward:  -3.01 | Avg:   2.07 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.756 📈 | LR: 1.43e-04
# Episode 5825 | Reward:  -4.29 | Avg:   3.31 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.755 📉 | LR: 1.43e-04
# Episode 5850 | Reward:  -3.68 | Avg:   2.60 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.753 📉 | LR: 1.43e-04
# Episode 5875 | Reward:  21.45 | Avg:   2.59 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.750 📉 | LR: 1.43e-04
# Episode 5900 | Reward:  -2.95 | Avg:   2.13 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.750 📉 | LR: 1.43e-04
# Episode 5925 | Reward:  -3.58 | Avg:   1.39 📈 | Success: 20.00% | Budget Exceeded: 80.00% 📉 | Entropy: 0.754 📈 | LR: 1.43e-04
# Episode 5950 | Reward:  -3.45 | Avg:   2.12 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.760 📈 | LR: 1.43e-04
# Episode 5975 | Reward:  -3.64 | Avg:   3.57 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.767 📈 | LR: 1.43e-04
# Episode 6000 | Reward:  -3.61 | Avg:   2.32 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.768 📉 | LR: 1.29e-04
# 💾 Model saved at episode 6000
# Episode 6025 | Reward:  19.99 | Avg:   2.06 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.761 📉 | LR: 1.29e-04
# Episode 6050 | Reward:  -3.15 | Avg:   2.02 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.758 📉 | LR: 1.29e-04
# Episode 6075 | Reward:  -3.47 | Avg:   0.85 📈 | Success: 18.00% | Budget Exceeded: 82.00% 📉 | Entropy: 0.758 📉 | LR: 1.29e-04
# Episode 6100 | Reward:  20.54 | Avg:   1.80 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.760 📈 | LR: 1.29e-04
# Episode 6125 | Reward:  -3.55 | Avg:   2.07 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.767 📈 | LR: 1.29e-04
# Episode 6150 | Reward:  -3.41 | Avg:   3.30 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.767 📉 | LR: 1.29e-04
# Episode 6175 | Reward:  -2.96 | Avg:   3.53 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.765 📈 | LR: 1.29e-04
# Episode 6200 | Reward:  -3.40 | Avg:   4.55 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.767 📉 | LR: 1.29e-04
# Episode 6225 | Reward:  -3.64 | Avg:   3.34 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.766 📈 | LR: 1.29e-04
# Episode 6250 | Reward:  -3.41 | Avg:   3.10 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.766 📈 | LR: 1.29e-04
# Episode 6275 | Reward:  21.46 | Avg:   3.09 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.763 📉 | LR: 1.29e-04
# Episode 6300 | Reward:  -3.61 | Avg:   1.61 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.756 📉 | LR: 1.29e-04
# Episode 6325 | Reward:  -3.45 | Avg:   1.89 📉 | Success: 22.00% | Budget Exceeded: 78.00% 📈 | Entropy: 0.753 📉 | LR: 1.29e-04
# Episode 6350 | Reward:  -3.18 | Avg:   2.16 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.752 📉 | LR: 1.29e-04
# Episode 6375 | Reward:  21.02 | Avg:   1.69 📈 | Success: 21.00% | Budget Exceeded: 79.00% 📉 | Entropy: 0.753 📈 | LR: 1.29e-04
# Episode 6400 | Reward:  -4.40 | Avg:   2.64 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.756 📉 | LR: 1.29e-04
# Episode 6425 | Reward:  21.18 | Avg:   3.80 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.756 📈 | LR: 1.29e-04
# Episode 6450 | Reward:  -3.38 | Avg:   2.04 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.756 📉 | LR: 1.29e-04
# Episode 6475 | Reward:  20.84 | Avg:   2.76 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.756 📈 | LR: 1.29e-04
# Episode 6500 | Reward:  -3.30 | Avg:   2.32 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.757 📈 | LR: 1.29e-04
# 💾 Model saved at episode 6500
# Episode 6525 | Reward:  -3.61 | Avg:   1.88 📈 | Success: 22.00% | Budget Exceeded: 78.00% 📉 | Entropy: 0.755 📈 | LR: 1.29e-04
# Episode 6550 | Reward:  -3.14 | Avg:   3.18 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.752 📉 | LR: 1.29e-04
# Episode 6575 | Reward:  -3.68 | Avg:   3.42 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.749 📉 | LR: 1.29e-04
# Episode 6600 | Reward:  -3.75 | Avg:   4.13 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.746 📉 | LR: 1.29e-04
# Episode 6625 | Reward:  20.45 | Avg:   4.60 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.740 📉 | LR: 1.29e-04
# Episode 6650 | Reward:  -3.20 | Avg:   4.81 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.738 📉 | LR: 1.29e-04
# Episode 6675 | Reward:  -3.49 | Avg:   3.85 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.736 📉 | LR: 1.29e-04
# Episode 6700 | Reward:  -3.51 | Avg:   3.86 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.730 📈 | LR: 1.29e-04
# Episode 6725 | Reward:  21.04 | Avg:   3.11 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.732 📉 | LR: 1.29e-04
# Episode 6750 | Reward:  -3.54 | Avg:   2.91 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.730 📉 | LR: 1.16e-04
# Episode 6775 | Reward:  -3.47 | Avg:   3.64 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.721 📉 | LR: 1.16e-04
# Episode 6800 | Reward:  -3.48 | Avg:   3.14 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.713 📉 | LR: 1.16e-04
# Episode 6825 | Reward:  -3.92 | Avg:   4.35 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.707 📉 | LR: 1.16e-04
# Episode 6850 | Reward:  -3.31 | Avg:   5.03 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.703 📈 | LR: 1.16e-04
# Episode 6875 | Reward:  21.28 | Avg:   5.01 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.703 📈 | LR: 1.16e-04
# Episode 6900 | Reward:  21.56 | Avg:   5.98 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.706 📉 | LR: 1.16e-04
# Episode 6925 | Reward:  -3.04 | Avg:   5.27 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.697 📉 | LR: 1.16e-04
# Episode 6950 | Reward:  21.43 | Avg:   4.78 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.691 📉 | LR: 1.16e-04
# Episode 6975 | Reward:  20.76 | Avg:   4.04 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.689 📉 | LR: 1.16e-04
# Episode 7000 | Reward:  -3.94 | Avg:   2.83 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.685 📈 | LR: 1.16e-04
# 💾 Model saved at episode 7000
# Episode 7025 | Reward:  -3.85 | Avg:   2.36 📉 | Success: 24.00% | Budget Exceeded: 76.00% 📈 | Entropy: 0.688 📈 | LR: 1.16e-04
# Episode 7050 | Reward:  -3.42 | Avg:   3.36 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.688 📉 | LR: 1.16e-04
# Episode 7075 | Reward:  -3.37 | Avg:   4.86 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.687 📉 | LR: 1.16e-04
# Episode 7100 | Reward:  -2.98 | Avg:   5.81 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.686 📉 | LR: 1.16e-04
# Episode 7125 | Reward:  -3.26 | Avg:   6.50 📉 | Success: 41.00% | Budget Exceeded: 59.00% 📈 | Entropy: 0.684 📉 | LR: 1.16e-04
# Episode 7150 | Reward:  -2.96 | Avg:   5.54 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.681 📉 | LR: 1.16e-04
# Episode 7175 | Reward:  -3.69 | Avg:   5.28 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.682 📉 | LR: 1.16e-04
# Episode 7200 | Reward:  20.03 | Avg:   5.01 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.682 📈 | LR: 1.16e-04
# Episode 7225 | Reward:  -3.47 | Avg:   3.82 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.685 📈 | LR: 1.16e-04
# Episode 7250 | Reward:  21.53 | Avg:   5.02 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.690 📈 | LR: 1.16e-04
# Episode 7275 | Reward:  20.50 | Avg:   3.54 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.689 📈 | LR: 1.16e-04
# Episode 7300 | Reward:  -4.25 | Avg:   2.61 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.692 📈 | LR: 1.16e-04
# Episode 7325 | Reward:  -3.06 | Avg:   4.51 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.695 📉 | LR: 1.16e-04
# Episode 7350 | Reward:  -3.24 | Avg:   3.79 📈 | Success: 30.00% | Budget Exceeded: 70.00% 📉 | Entropy: 0.693 📈 | LR: 1.16e-04
# Episode 7375 | Reward:  -3.79 | Avg:   5.49 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.693 📉 | LR: 1.16e-04
# Episode 7400 | Reward:  -3.05 | Avg:   5.72 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.693 📉 | LR: 1.16e-04
# Episode 7425 | Reward:  -3.62 | Avg:   5.01 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.691 📉 | LR: 1.16e-04
# Episode 7450 | Reward:  -4.22 | Avg:   4.71 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.689 📈 | LR: 1.16e-04
# Episode 7475 | Reward:  -3.36 | Avg:   4.23 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.693 📉 | LR: 1.16e-04
# Episode 7500 | Reward:  -3.31 | Avg:   3.98 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.692 📉 | LR: 1.05e-04
# 💾 Model saved at episode 7500
# Episode 7525 | Reward:  -3.44 | Avg:   4.48 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.694 📈 | LR: 1.05e-04
# Episode 7550 | Reward:  -3.21 | Avg:   3.03 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.696 📉 | LR: 1.05e-04
# Episode 7575 | Reward:  -3.81 | Avg:   2.30 📈 | Success: 24.00% | Budget Exceeded: 76.00% 📉 | Entropy: 0.694 📈 | LR: 1.05e-04
# Episode 7600 | Reward:  20.70 | Avg:   2.79 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.693 📉 | LR: 1.05e-04
# Episode 7625 | Reward:  -3.83 | Avg:   3.01 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.694 📉 | LR: 1.05e-04
# Episode 7650 | Reward:  -3.29 | Avg:   4.50 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.702 📈 | LR: 1.05e-04
# Episode 7675 | Reward:  -3.63 | Avg:   5.53 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.709 📈 | LR: 1.05e-04
# Episode 7700 | Reward:  -3.87 | Avg:   5.52 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.710 📈 | LR: 1.05e-04
# Episode 7725 | Reward:  -3.15 | Avg:   4.12 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.709 📉 | LR: 1.05e-04
# Episode 7750 | Reward:  20.76 | Avg:   3.60 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.706 📉 | LR: 1.05e-04
# Episode 7775 | Reward:  -3.42 | Avg:   2.82 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.701 📈 | LR: 1.05e-04
# Episode 7800 | Reward:  21.16 | Avg:   3.54 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.704 📈 | LR: 1.05e-04
# Episode 7825 | Reward:  -3.35 | Avg:   3.48 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.706 📉 | LR: 1.05e-04
# Episode 7850 | Reward:  20.53 | Avg:   3.73 📈 | Success: 30.00% | Budget Exceeded: 70.00% 📉 | Entropy: 0.701 📈 | LR: 1.05e-04
# Episode 7875 | Reward:  21.64 | Avg:   3.74 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.707 📈 | LR: 1.05e-04
# Episode 7900 | Reward:  -3.49 | Avg:   4.04 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.701 📉 | LR: 1.05e-04
# Episode 7925 | Reward:  -3.53 | Avg:   5.50 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.701 📈 | LR: 1.05e-04
# Episode 7950 | Reward:  -3.47 | Avg:   5.75 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.706 📉 | LR: 1.05e-04
# Episode 7975 | Reward:  20.88 | Avg:   5.97 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.705 📈 | LR: 1.05e-04
# Episode 8000 | Reward:  20.88 | Avg:   4.95 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.711 📉 | LR: 1.05e-04
# 💾 Model saved at episode 8000
# Episode 8025 | Reward:  20.94 | Avg:   5.22 📈 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.708 📉 | LR: 1.05e-04
# Episode 8050 | Reward:  21.33 | Avg:   4.75 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.710 📉 | LR: 1.05e-04
# Episode 8075 | Reward:  20.71 | Avg:   5.03 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.709 📈 | LR: 1.05e-04
# Episode 8100 | Reward:  -3.75 | Avg:   4.58 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.715 📈 | LR: 1.05e-04
# Episode 8125 | Reward:  -4.06 | Avg:   3.09 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.720 📉 | LR: 1.05e-04
# Episode 8150 | Reward:  20.14 | Avg:   2.84 📉 | Success: 26.00% | Budget Exceeded: 74.00% 📈 | Entropy: 0.715 📈 | LR: 1.05e-04
# Episode 8175 | Reward:  -3.26 | Avg:   2.60 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.714 📉 | LR: 1.05e-04
# Episode 8200 | Reward:  20.68 | Avg:   3.56 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.707 📉 | LR: 1.05e-04
# Episode 8225 | Reward:  -3.24 | Avg:   4.33 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.705 📈 | LR: 1.05e-04
# Episode 8250 | Reward:  -3.35 | Avg:   5.06 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.704 📉 | LR: 9.41e-05
# Episode 8275 | Reward:  -3.09 | Avg:   4.57 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.704 📈 | LR: 9.41e-05
# Episode 8300 | Reward:  -3.12 | Avg:   4.34 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.703 📉 | LR: 9.41e-05
# Episode 8325 | Reward:  -3.14 | Avg:   3.11 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.694 📉 | LR: 9.41e-05
# Episode 8350 | Reward:  -3.37 | Avg:   2.16 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.695 📉 | LR: 9.41e-05
# Episode 8375 | Reward:  20.70 | Avg:   2.60 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.688 📉 | LR: 9.41e-05
# Episode 8400 | Reward:  20.87 | Avg:   2.81 📈 | Success: 26.00% | Budget Exceeded: 74.00% 📉 | Entropy: 0.692 📈 | LR: 9.41e-05
# Episode 8425 | Reward:  21.46 | Avg:   4.77 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.694 📉 | LR: 9.41e-05
# Episode 8450 | Reward:  20.25 | Avg:   5.73 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.688 📈 | LR: 9.41e-05
# Episode 8475 | Reward:  21.81 | Avg:   6.51 📈 | Success: 41.00% | Budget Exceeded: 59.00% 📉 | Entropy: 0.689 📉 | LR: 9.41e-05
# Episode 8500 | Reward:  -3.72 | Avg:   6.50 📉 | Success: 41.00% | Budget Exceeded: 59.00% 📈 | Entropy: 0.682 📉 | LR: 9.41e-05
# 💾 Model saved at episode 8500
# Episode 8525 | Reward:  -3.57 | Avg:   5.02 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.682 📈 | LR: 9.41e-05
# Episode 8550 | Reward:  21.05 | Avg:   5.75 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.684 📉 | LR: 9.41e-05
# Episode 8575 | Reward:  20.81 | Avg:   5.75 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.685 📈 | LR: 9.41e-05
# Episode 8600 | Reward:  21.25 | Avg:   5.81 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.685 📉 | LR: 9.41e-05
# Episode 8625 | Reward:  -3.71 | Avg:   6.01 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.682 📉 | LR: 9.41e-05
# Episode 8650 | Reward:  -3.24 | Avg:   5.54 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.675 📉 | LR: 9.41e-05
# Episode 8675 | Reward:  -3.49 | Avg:   4.77 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.668 📉 | LR: 9.41e-05
# Episode 8700 | Reward:  -3.68 | Avg:   4.97 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.667 📉 | LR: 9.41e-05
# Episode 8725 | Reward:  -3.48 | Avg:   5.51 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.666 📈 | LR: 9.41e-05
# Episode 8750 | Reward:  21.39 | Avg:   6.01 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.668 📈 | LR: 9.41e-05
# Episode 8775 | Reward:  -3.58 | Avg:   6.77 📈 | Success: 42.00% | Budget Exceeded: 58.00% 📉 | Entropy: 0.667 📉 | LR: 9.41e-05
# Episode 8800 | Reward:  21.10 | Avg:   7.00 📈 | Success: 43.00% | Budget Exceeded: 57.00% 📉 | Entropy: 0.665 📉 | LR: 9.41e-05
# Episode 8825 | Reward:  -3.51 | Avg:   6.51 📉 | Success: 41.00% | Budget Exceeded: 59.00% 📈 | Entropy: 0.664 📉 | LR: 9.41e-05
# Episode 8850 | Reward:  -3.91 | Avg:   6.46 📉 | Success: 41.00% | Budget Exceeded: 59.00% 📈 | Entropy: 0.663 📈 | LR: 9.41e-05
# Episode 8875 | Reward:  -2.94 | Avg:   5.48 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.662 📉 | LR: 9.41e-05
# Episode 8900 | Reward:  -3.74 | Avg:   6.50 📈 | Success: 41.00% | Budget Exceeded: 59.00% 📉 | Entropy: 0.664 📉 | LR: 9.41e-05
# Episode 8925 | Reward:  -3.53 | Avg:   7.88 📉 | Success: 47.00% | Budget Exceeded: 53.00% 📈 | Entropy: 0.663 📈 | LR: 9.41e-05
# Episode 8950 | Reward:  21.74 | Avg:   7.66 📈 | Success: 46.00% | Budget Exceeded: 54.00% 📉 | Entropy: 0.665 📈 | LR: 9.41e-05
# Episode 8975 | Reward:  21.03 | Avg:   8.39 📉 | Success: 49.00% | Budget Exceeded: 51.00% 📈 | Entropy: 0.669 📉 | LR: 9.41e-05
# Episode 9000 | Reward:  -3.17 | Avg:   6.18 📉 | Success: 40.00% | Budget Exceeded: 60.00% 📈 | Entropy: 0.665 📈 | LR: 8.47e-05
# 💾 Model saved at episode 9000
# Episode 9025 | Reward:  -3.69 | Avg:   4.98 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.664 📉 | LR: 8.47e-05
# Episode 9050 | Reward:  20.67 | Avg:   3.75 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.665 📉 | LR: 8.47e-05
# Episode 9075 | Reward:  -3.16 | Avg:   3.26 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.664 📈 | LR: 8.47e-05
# Episode 9100 | Reward:  -3.45 | Avg:   3.97 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.670 📈 | LR: 8.47e-05
# Episode 9125 | Reward:  -3.77 | Avg:   3.53 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.675 📈 | LR: 8.47e-05
# Episode 9150 | Reward:  -3.20 | Avg:   4.02 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.680 📈 | LR: 8.47e-05
# Episode 9175 | Reward:  21.43 | Avg:   5.00 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.685 📈 | LR: 8.47e-05
# Episode 9200 | Reward:  -3.50 | Avg:   4.05 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.685 📈 | LR: 8.47e-05
# ...
# Episode 247150 | Reward:  -3.87 | Avg:   3.09 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.650 📉 | LR: 2.65e-19
# Episode 247175 | Reward:  20.48 | Avg:   5.27 📈 | Success: 36.00% | Budget Exceeded: 64.00% 📉 | Entropy: 0.646 📈 | LR: 2.65e-19
# Episode 247200 | Reward:  -3.21 | Avg:   5.27 📈 | Success: 36.00% | Budget Exceeded: 64.00% 📉 | Entropy: 0.647 📉 | LR: 2.65e-19
# Episode 247225 | Reward:  -3.14 | Avg:   5.26 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.648 📈 | LR: 2.65e-19
# Episode 247250 | Reward:  -3.27 | Avg:   4.28 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.650 📈 | LR: 2.65e-19
# Episode 247275 | Reward:  20.06 | Avg:   3.31 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.655 📈 | LR: 2.65e-19
# Episode 247300 | Reward:  20.85 | Avg:   3.76 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.658 📈 | LR: 2.65e-19
# Episode 247325 | Reward:  -3.43 | Avg:   4.75 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.655 📈 | LR: 2.65e-19
# Episode 247350 | Reward:  -3.84 | Avg:   5.96 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.654 📉 | LR: 2.65e-19
# Episode 247375 | Reward:  -3.45 | Avg:   5.24 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.654 📉 | LR: 2.65e-19
# Episode 247400 | Reward:  -3.43 | Avg:   4.78 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.651 📈 | LR: 2.65e-19
# Episode 247425 | Reward:  -3.65 | Avg:   3.97 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.656 📈 | LR: 2.65e-19
# Episode 247450 | Reward:  -4.04 | Avg:   4.96 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.662 📉 | LR: 2.65e-19
# Episode 247475 | Reward:  20.52 | Avg:   6.68 📈 | Success: 42.00% | Budget Exceeded: 58.00% 📉 | Entropy: 0.656 📈 | LR: 2.65e-19
# Episode 247500 | Reward:  -3.42 | Avg:   6.20 📈 | Success: 40.00% | Budget Exceeded: 60.00% 📉 | Entropy: 0.657 📉 | LR: 2.38e-19
# 💾 Model saved at episode 247500
# Episode 247525 | Reward:  -3.69 | Avg:   5.76 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.656 📉 | LR: 2.38e-19
# Episode 247550 | Reward:  -4.38 | Avg:   3.30 📉 | Success: 28.00% | Budget Exceeded: 72.00% 📈 | Entropy: 0.652 📈 | LR: 2.38e-19
# Episode 247575 | Reward:  20.09 | Avg:   1.31 📉 | Success: 20.00% | Budget Exceeded: 80.00% 📈 | Entropy: 0.652 📉 | LR: 2.38e-19
# Episode 247600 | Reward:  -3.47 | Avg:   1.06 📉 | Success: 19.00% | Budget Exceeded: 81.00% 📈 | Entropy: 0.653 📉 | LR: 2.38e-19
# Episode 247625 | Reward:  20.51 | Avg:   2.52 📈 | Success: 25.00% | Budget Exceeded: 75.00% 📉 | Entropy: 0.654 📈 | LR: 2.38e-19
# Episode 247650 | Reward:  20.99 | Avg:   4.03 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.657 📈 | LR: 2.38e-19
# Episode 247675 | Reward:  -3.45 | Avg:   4.99 📈 | Success: 35.00% | Budget Exceeded: 65.00% 📉 | Entropy: 0.651 📉 | LR: 2.38e-19
# Episode 247700 | Reward:  20.68 | Avg:   5.95 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.651 📉 | LR: 2.38e-19
# Episode 247725 | Reward:  -3.09 | Avg:   5.23 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.649 📉 | LR: 2.38e-19
# Episode 247750 | Reward:  -3.86 | Avg:   4.44 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.650 📈 | LR: 2.38e-19
# Episode 247775 | Reward:  -3.35 | Avg:   5.43 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.657 📉 | LR: 2.38e-19
# Episode 247800 | Reward:  21.70 | Avg:   5.70 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.654 📉 | LR: 2.38e-19
# Episode 247825 | Reward:  20.70 | Avg:   5.93 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.654 📉 | LR: 2.38e-19
# Episode 247850 | Reward:  -3.55 | Avg:   5.74 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.653 📈 | LR: 2.38e-19
# Episode 247875 | Reward:  -3.45 | Avg:   5.27 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.659 📈 | LR: 2.38e-19
# Episode 247900 | Reward:  20.77 | Avg:   4.51 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.658 📈 | LR: 2.38e-19
# Episode 247925 | Reward:  -3.31 | Avg:   4.33 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.663 📉 | LR: 2.38e-19
# Episode 247950 | Reward:  -3.24 | Avg:   5.30 📈 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.656 📉 | LR: 2.38e-19
# Episode 247975 | Reward:  -3.63 | Avg:   5.52 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.652 📈 | LR: 2.38e-19
# Episode 248000 | Reward:  -3.26 | Avg:   5.29 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.653 📉 | LR: 2.38e-19
# 💾 Model saved at episode 248000
# Episode 248025 | Reward:  20.82 | Avg:   6.00 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.648 📈 | LR: 2.38e-19
# Episode 248050 | Reward:  20.25 | Avg:   6.43 📈 | Success: 41.00% | Budget Exceeded: 59.00% 📉 | Entropy: 0.650 📉 | LR: 2.38e-19
# Episode 248075 | Reward:  20.84 | Avg:   5.73 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.651 📈 | LR: 2.38e-19
# Episode 248100 | Reward:  19.94 | Avg:   6.24 📉 | Success: 40.00% | Budget Exceeded: 60.00% 📈 | Entropy: 0.650 📉 | LR: 2.38e-19
# Episode 248125 | Reward:  20.18 | Avg:   5.25 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.649 📈 | LR: 2.38e-19
# Episode 248150 | Reward:  -2.93 | Avg:   4.31 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.647 📉 | LR: 2.38e-19
# Episode 248175 | Reward:  -3.73 | Avg:   4.08 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.643 📉 | LR: 2.38e-19
# Episode 248200 | Reward:  20.84 | Avg:   3.05 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.643 📉 | LR: 2.38e-19
# Episode 248225 | Reward:  -3.34 | Avg:   2.58 📉 | Success: 25.00% | Budget Exceeded: 75.00% 📈 | Entropy: 0.649 📈 | LR: 2.38e-19
# Episode 248250 | Reward:  -4.17 | Avg:   2.06 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.650 📈 | LR: 2.14e-19
# Episode 248275 | Reward:  20.56 | Avg:   3.23 📈 | Success: 28.00% | Budget Exceeded: 72.00% 📉 | Entropy: 0.650 📈 | LR: 2.14e-19
# Episode 248300 | Reward:  20.88 | Avg:   3.99 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.651 📉 | LR: 2.14e-19
# Episode 248325 | Reward:  -3.98 | Avg:   4.00 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.643 📉 | LR: 2.14e-19
# Episode 248350 | Reward:  21.28 | Avg:   4.03 📉 | Success: 31.00% | Budget Exceeded: 69.00% 📈 | Entropy: 0.644 📈 | LR: 2.14e-19
# Episode 248375 | Reward:  20.08 | Avg:   3.06 📉 | Success: 27.00% | Budget Exceeded: 73.00% 📈 | Entropy: 0.650 📉 | LR: 2.14e-19
# Episode 248400 | Reward:  20.85 | Avg:   4.06 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.647 📈 | LR: 2.14e-19
# Episode 248425 | Reward:  20.85 | Avg:   4.31 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.655 📈 | LR: 2.14e-19
# Episode 248450 | Reward:  -3.48 | Avg:   4.80 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.656 📉 | LR: 2.14e-19
# Episode 248475 | Reward:  21.99 | Avg:   6.76 📉 | Success: 42.00% | Budget Exceeded: 58.00% 📈 | Entropy: 0.656 📈 | LR: 2.14e-19
# Episode 248500 | Reward:  -3.96 | Avg:   6.00 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.658 📉 | LR: 2.14e-19
# 💾 Model saved at episode 248500
# Episode 248525 | Reward:  21.11 | Avg:   6.42 📈 | Success: 41.00% | Budget Exceeded: 59.00% 📉 | Entropy: 0.651 📉 | LR: 2.14e-19
# Episode 248550 | Reward:  -3.97 | Avg:   6.71 📉 | Success: 42.00% | Budget Exceeded: 58.00% 📈 | Entropy: 0.649 📉 | LR: 2.14e-19
# Episode 248575 | Reward:  21.00 | Avg:   5.49 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.645 📉 | LR: 2.14e-19
# Episode 248600 | Reward:  -3.58 | Avg:   6.26 📈 | Success: 40.00% | Budget Exceeded: 60.00% 📈 | Entropy: 0.641 📈 | LR: 2.14e-19
# Episode 248625 | Reward:  20.72 | Avg:   5.80 📈 | Success: 38.00% | Budget Exceeded: 62.00% 📉 | Entropy: 0.640 📉 | LR: 2.14e-19
# Episode 248650 | Reward:  -3.58 | Avg:   6.00 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.644 📈 | LR: 2.14e-19
# Episode 248675 | Reward:  -3.63 | Avg:   5.78 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.640 📈 | LR: 2.14e-19
# Episode 248700 | Reward:  -3.84 | Avg:   4.54 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.642 📈 | LR: 2.14e-19
# Episode 248725 | Reward:  -4.18 | Avg:   5.74 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.649 📉 | LR: 2.14e-19
# Episode 248750 | Reward:  -3.98 | Avg:   5.52 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.645 📈 | LR: 2.14e-19
# Episode 248775 | Reward:  -2.90 | Avg:   4.53 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.650 📈 | LR: 2.14e-19
# Episode 248800 | Reward:  -3.29 | Avg:   5.25 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.656 📉 | LR: 2.14e-19
# Episode 248825 | Reward:  20.23 | Avg:   4.34 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.653 📈 | LR: 2.14e-19
# Episode 248850 | Reward:  -3.45 | Avg:   3.12 📈 | Success: 27.00% | Budget Exceeded: 73.00% 📉 | Entropy: 0.658 📈 | LR: 2.14e-19
# Episode 248875 | Reward:  -3.71 | Avg:   3.86 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.658 📉 | LR: 2.14e-19
# Episode 248900 | Reward:  21.29 | Avg:   4.41 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.655 📈 | LR: 2.14e-19
# Episode 248925 | Reward:  20.79 | Avg:   4.38 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.654 📉 | LR: 2.14e-19
# Episode 248950 | Reward:  -2.70 | Avg:   6.14 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.653 📈 | LR: 2.14e-19
# Episode 248975 | Reward:  -3.01 | Avg:   5.88 📉 | Success: 38.00% | Budget Exceeded: 62.00% 📈 | Entropy: 0.658 📈 | LR: 2.14e-19
# Episode 249000 | Reward:  -3.11 | Avg:   4.39 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.655 📈 | LR: 1.93e-19
# 💾 Model saved at episode 249000
# Episode 249025 | Reward:  20.18 | Avg:   5.33 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.657 📉 | LR: 1.93e-19
# Episode 249050 | Reward:  -3.23 | Avg:   4.04 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.657 📉 | LR: 1.93e-19
# Episode 249075 | Reward:  21.10 | Avg:   4.32 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.655 📈 | LR: 1.93e-19
# Episode 249100 | Reward:  -3.45 | Avg:   4.79 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.654 📉 | LR: 1.93e-19
# Episode 249125 | Reward:  -3.35 | Avg:   3.66 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.654 📉 | LR: 1.93e-19
# Episode 249150 | Reward:  -4.04 | Avg:   3.63 📉 | Success: 29.00% | Budget Exceeded: 71.00% 📈 | Entropy: 0.650 📉 | LR: 1.93e-19
# Episode 249175 | Reward:  20.65 | Avg:   3.59 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.647 📈 | LR: 1.93e-19
# Episode 249200 | Reward:  -3.38 | Avg:   4.29 📉 | Success: 32.00% | Budget Exceeded: 68.00% 📈 | Entropy: 0.648 📉 | LR: 1.93e-19
# Episode 249225 | Reward:  -3.59 | Avg:   4.03 📈 | Success: 31.00% | Budget Exceeded: 69.00% 📉 | Entropy: 0.643 📈 | LR: 1.93e-19
# Episode 249250 | Reward:  -3.53 | Avg:   4.75 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.648 📉 | LR: 1.93e-19
# Episode 249275 | Reward:  -3.53 | Avg:   4.50 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.651 📈 | LR: 1.93e-19
# Episode 249300 | Reward:  20.72 | Avg:   4.28 📈 | Success: 32.00% | Budget Exceeded: 68.00% 📉 | Entropy: 0.647 📈 | LR: 1.93e-19
# Episode 249325 | Reward:  -3.56 | Avg:   4.75 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.650 📉 | LR: 1.93e-19
# Episode 249350 | Reward:  -3.02 | Avg:   4.53 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.649 📉 | LR: 1.93e-19
# Episode 249375 | Reward:  -3.29 | Avg:   4.54 📉 | Success: 33.00% | Budget Exceeded: 67.00% 📈 | Entropy: 0.645 📈 | LR: 1.93e-19
# Episode 249400 | Reward:  -3.96 | Avg:   4.79 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.647 📈 | LR: 1.93e-19
# Episode 249425 | Reward:  -3.05 | Avg:   5.31 📈 | Success: 36.00% | Budget Exceeded: 64.00% 📉 | Entropy: 0.650 📉 | LR: 1.93e-19
# Episode 249450 | Reward:  20.05 | Avg:   5.54 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.649 📉 | LR: 1.93e-19
# Episode 249475 | Reward:  21.62 | Avg:   6.76 📈 | Success: 42.00% | Budget Exceeded: 58.00% 📉 | Entropy: 0.653 📈 | LR: 1.93e-19
# Episode 249500 | Reward:  -3.27 | Avg:   6.27 📉 | Success: 40.00% | Budget Exceeded: 60.00% 📈 | Entropy: 0.659 📈 | LR: 1.93e-19
# 💾 Model saved at episode 249500
# Episode 249525 | Reward:  -3.43 | Avg:   6.01 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.656 📈 | LR: 1.93e-19
# Episode 249550 | Reward:  -3.20 | Avg:   6.51 📉 | Success: 41.00% | Budget Exceeded: 59.00% 📈 | Entropy: 0.650 📉 | LR: 1.93e-19
# Episode 249575 | Reward:  -3.38 | Avg:   6.27 📈 | Success: 40.00% | Budget Exceeded: 60.00% 📉 | Entropy: 0.643 📉 | LR: 1.93e-19
# Episode 249600 | Reward:  -3.52 | Avg:   6.02 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.646 📈 | LR: 1.93e-19
# Episode 249625 | Reward:  20.13 | Avg:   5.53 📉 | Success: 37.00% | Budget Exceeded: 63.00% 📈 | Entropy: 0.646 📈 | LR: 1.93e-19
# Episode 249650 | Reward:  21.71 | Avg:   3.84 📉 | Success: 30.00% | Budget Exceeded: 70.00% 📈 | Entropy: 0.653 📈 | LR: 1.93e-19
# Episode 249675 | Reward:  -3.61 | Avg:   2.16 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.659 📉 | LR: 1.93e-19
# Episode 249700 | Reward:  -3.38 | Avg:   2.12 📉 | Success: 23.00% | Budget Exceeded: 77.00% 📈 | Entropy: 0.656 📈 | LR: 1.93e-19
# Episode 249725 | Reward:  -3.28 | Avg:   2.14 📈 | Success: 23.00% | Budget Exceeded: 77.00% 📉 | Entropy: 0.659 📈 | LR: 1.93e-19
# Episode 249750 | Reward:  21.16 | Avg:   3.54 📈 | Success: 29.00% | Budget Exceeded: 71.00% 📉 | Entropy: 0.657 📉 | LR: 1.74e-19
# Episode 249775 | Reward:  -3.63 | Avg:   4.49 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.651 📉 | LR: 1.74e-19
# Episode 249800 | Reward:  -3.92 | Avg:   5.96 📈 | Success: 39.00% | Budget Exceeded: 61.00% 📉 | Entropy: 0.650 📉 | LR: 1.74e-19
# Episode 249825 | Reward:  -3.65 | Avg:   5.97 📉 | Success: 39.00% | Budget Exceeded: 61.00% 📈 | Entropy: 0.642 📉 | LR: 1.74e-19
# Episode 249850 | Reward:  20.73 | Avg:   5.52 📈 | Success: 37.00% | Budget Exceeded: 63.00% 📉 | Entropy: 0.643 📈 | LR: 1.74e-19
# Episode 249875 | Reward:  -3.34 | Avg:   5.29 📉 | Success: 36.00% | Budget Exceeded: 64.00% 📈 | Entropy: 0.645 📉 | LR: 1.74e-19
# Episode 249900 | Reward:  22.23 | Avg:   4.63 📈 | Success: 33.00% | Budget Exceeded: 67.00% 📉 | Entropy: 0.646 📈 | LR: 1.74e-19
# Episode 249925 | Reward:  20.07 | Avg:   4.85 📈 | Success: 34.00% | Budget Exceeded: 66.00% 📉 | Entropy: 0.651 📉 | LR: 1.74e-19
# Episode 249950 | Reward:  -3.26 | Avg:   3.87 📈 | Success: 30.00% | Budget Exceeded: 70.00% 📉 | Entropy: 0.651 📈 | LR: 1.74e-19
# Episode 249975 | Reward:  -2.54 | Avg:   4.86 📉 | Success: 34.00% | Budget Exceeded: 66.00% 📈 | Entropy: 0.653 📈 | LR: 1.74e-19
# Episode 250000 | Reward:  -3.15 | Avg:   5.05 📉 | Success: 35.00% | Budget Exceeded: 65.00% 📈 | Entropy: 0.654 📈 | LR: 1.74e-19
# 💾 Model saved at episode 250000
#
# ==========================================================================================
# BUDGET-AWARE TRAINING COMPLETED
# ==========================================================================================
# Training time: 5594.55 seconds
# Best average reward (last 100): 9.396
# Final average reward (last 100): 5.046
# Final success rate (last 100): 35.00%
# Final budget exceeded rate (last 100): 65.00% 🎯
# Final entropy: 0.654 (max possible: 1.386)
# Final learning rate: 1.74e-19
# First positive reward: Episode 9
# Learning rate decayed 333 times during training
# Budget-aware training curves saved to plots/budget_aware_training_curves.png
# Figure(2000x1500)
#
# Evaluating trained model...
#
# Evaluating budget-aware policy over 100 episodes...
# Budget-Aware Evaluation Results:
#   Mean Reward: 11.057 ± 12.023
#   Mean Length: 11.29
#   Mean Cost: 122.86
#   Mean Skill Improvement: 2.638
#   Mean Budget Utilization: 60.00%
#   Success Rate: 60.00% 🎯
#   Budget Exceeded Rate: 40.00% 💰
#   Reward Improvement from Start: +13.529
#
# Enhanced system execution completed.
